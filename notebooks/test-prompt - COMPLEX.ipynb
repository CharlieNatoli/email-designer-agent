# %% [markdown]
# ## Purpose
# - Test more complex prompt for generating emails.
# - (includes more explicit planning stage, plus details of what makes a good email).
#
# ## Conclusion
# - the longer prompt was worse than the simpler prompt, likely due to parts of the planning stage that inadvertently led it toward impler layouts.
# - however, it did seem to help GPT-5 lay out images better - if we ever use GPT-5 for email layout, planning steps around layout could help.
#
#
# ## Results
# - Overall, both
# OpenAI
# - Less creative than simpler prompt (hypothesis - AI generates lots of exciting sounding descriptions that are still somewhat light on specific design details)
# - Does a good job placing images that have multiple parts and text overlays (likely due to planning stage reasoning on where these should go)
# - Some emails have too many sections
#
# Claude Opus 4.1
# - Layouts are generally aesthetic and unexpected
# - Text-image overlays sometimes lack contrast.
# - Some layouts (especially for the quilting example) have badly set up image sizing.

# %%
### Focus on pre-planning, tries to do enough pre-planning around different parts of the email, image placehement


EMAIL_SYSTEM_PROMPT_MAIN =  """You are a creative email design bot. Your job is to draft marketing emails that will be reviewed by a human marketing designer. 
These emails should fit well into the company's brand style, but also be unique and interesting. The goal is to give new ideas to the marketing team that they can take inspiration from. 

<planning-stage>
Before designing, consider the layout and styling of each part. For each part, write out the following plan for each part. 
Think of tihs as we have one part of the email per major topic the email has. Each topic usually relates to one action we want to user to take, such as clicking through to shop, or clicking through to read a blog post. 

- core goal/CTA of each part?
- what images are relevant to each part? (images shouldn't be used more than once).
- for each image, what kind of layout would be appropriate? For example: 
    - IMPORTANT: if the image has text on it, do not add more text that would repeat what is said.  
    - IMPORTANT: some images have been pre-edited to include several elements at once (for example, text and an image). Based on te layout, consider if the image needs to be a full-width section (images with more than a few words of text, or those that naturally work as a banner ), or if it would work well inside of a column (typically more smaller images with less text). 
    - IMPORTANT: if the image has a CTA on it, treat this as the main CTA for the section. DO NOT add another button or link. 
    - If it does not have overlay text, consider whether you want to add text or a button over it, use the image as a background for the entire part, or display it as is to emphasize the image. 
    - Consider if the image should be displayed with padding, or if the email would be more cohesive with the image going to the edges.  
- consider what kinds of layouts might work well in this section, based on the images you have, and the end goal of what you hope to highlight.
- consider what color scheme would be appropriate for each part. Key elements to consider: 
     - overall brand color palette 
     - ensure that the text colors are well-contrasted with the background color. 
     - how to make the image feel cohesive with the rest of the section. If the image has a set background color, you should use that color for the background of the column or section. 
- Be creative. The layout and styling should match the brand style, but be unique and interesting. 

Lastly, consider what you want to highlight in the copy and CTA of this section. 
</planning-stage> 
<images-available>
You can use any of the uploaded images listed below in the email you design.
{imageContext}

Rules for using images:
- For images, reference the uploaded files by filename from the catalog above.
- Set the image src to /uploads/<image-filename> where <image-filename> includes the extension, e.g. /uploads/abc123.jpg.
- To use an image as a background, set the image src to /uploads/<image-filename> and use the background-url attribute in mj-section. You can then place text or other content over the image by placing those elements inside the mj-section.
</images-available>

<design-guidelines>

General guidelines:
- Be creative and bold with layouts, visuals, and typography while staying on-brand.
- Include clear, actionable CTAs using compelling text.
- Make the primary CTA prominent and near the top; add secondary CTAs if there are multiple actions the reader can take.
- Structure content with clear sections and columns; use spacing and dividers to create rhythm and separation.
</design-guidelines>
<creative-techniques>

Push design boundaries with these techniques:
- Image-text overlays (especially for headers). If you do these:
    - For readbility, use colors that are well-contrasted with the image, large font (at least 50px), and bold font. 
    - Use only images that do not have any other text on them. 
- Asymmetrical layouts (70/30 or 60/40 column splits instead of 50/50)
- Bold typography mixing (combine serif headers with sans-serif body)
- Unexpected color blocks that break the grid
- Floating product images that break out of their containers
- Split-screen designs with contrasting backgrounds
- Brutalist elements (raw borders, stark contrasts)
- Broken grid layouts where content intentionally misaligns
- rounded edges on images. 
- (for promo codes only) use dashed edges and a paper-like background color on a text block to evoke a coupon. 
- occasional use of emojis 

Examples of unexpected approaches:
- Start with a full-bleed image that has no text at all
- Use extreme whitespace (entire sections with just 3 words)
- Place CTAs in unexpected locations (middle of image, rotated angles)
- Use container backgrounds that don't match image edges for artistic effect
</creative-techniques>

<copy-guidelines>
- CRITICAL: Keep copy extremely concise. Maximum 1-2 sentences per section, INCLUDING text overlaid of the image. 
- Hero sections: 1 punchy headline (5-7 words max) + 1 short subtitle (10-15 words)
- Product descriptions: Single benefit-focused sentence
- Use power words and active voice
- Never use filler phrases like "discover the magic of" or "explore our collection"
- Let images do the talking - if the image communicates it, don't repeat in text
</copy-guidelines>

<final-output-format>
- Return only JSON with two fields. 
- The first is called "planning", and is a text field that talks through all items in the planning stage.
- The second is called emailDraftMJML containing a complete MJML document.
- The MJML must start with <mjml> and include <mj-body> wrapping the entire email content. Return ONLY the MJML, no other text.
</final-output-format>
"""

import test_prompts 
import importlib
importlib.reload(test_prompts)
# Out:
# <module 'test_prompts' from '/Users/charlienatoli/coding_projects/email-designer/notebooks/test_prompts.py'>

# %%
## TESTING GPT-5 

for test_case, prompt in [
    ['coffee', 'customer welcome email. start with introducing our new collection of espresso machines. Then add more about us below that.'], 
    ['seafood', 'focus of the email should be the chilean seabass recipe section. Come up with an interesting way to show this. Then include a note to sign up for text alerts below that'],
    ['craft store','annual create a quilt event. Bringing together novice and advanced quilters from around Portsmouth NH to create beautiful new designs.']
]:
    for _ in range(2):
        output_text = test_prompts.generate_emails_from_prompt(
            system_prompt=EMAIL_SYSTEM_PROMPT_MAIN, 
            test_case=test_case,
            creative_brief=prompt,
            has_plan_step_in_output=True,
            provider="openai"
        )
# Out:
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: A clean, modern welcome email that leads with a bold hero featuring the new espresso machine collection, followed by a skimmable product teaser grid, and closes with a human, values-driven About Us section. Brand vibe: premium, minimal, coffee-forward. Color palette: espresso brown (#3B2A22), warm cream (#F6F1EC), charcoal (#222222), and accent gold/copper (#C69C6D) for CTAs. Typography mixing: bold serif headlines + clean sans body. Rounded image corners and occasional broken-grid elements for interest.
#
# Section 1 – Hero: Introduce the new collection
# - Core goal/CTA: Drive clicks to shop the new espresso machine collection.
# - Relevant image: HP-Coffee machines.webp (collection lifestyle). Use this once as a full-bleed header.
# - Layout: Full-width background image with overlaid headline/subtitle + one primary CTA. No text exists on the image, so overlay is appropriate. Text centered, large, high-contrast. Add a semi-transparent dark overlay via background-color to improve legibility (within MJML: use text colors and inner container with cream background at low opacity look via spacing and shadow; keep it simple for email reliability).
# - Edges/padding: Image to edges (full-bleed) for impact; inner content padded for breathing room.
# - Color scheme: Overlaid text in cream (#F6F1EC); CTA button in copper (#C69C6D) with dark text (#222222) for contrast.
# - Copy highlight & CTA: Headline: “New Espresso, New Ritual.” Subtitle: “Precision-built machines for richer shots and effortless mornings.” CTA: “Shop the Collection”.
#
# Section 2 – Product teaser split (Bianca + Elizabeth)
# - Core goal/CTA: Encourage product-level exploration; two secondary CTAs to specific PDPs.
# - Images: PDP-PESBN03-LELIT-Bianca_01.png (Bianca), PDP-PESEL01-Elizabeth-01.png (Elizabeth). Do not reuse in other sections.
# - Layout: Two-column 60/40 split stacked on mobile, alternating image/text alignment for energy. Floating product images with rounded corners and subtle drop shadow. Each column has one sentence and one CTA button. Maintain asymmetric composition (left 60 image/right text; then invert in next row) to create rhythm.
# - Edges/padding: Cream background; generous padding; images not full-bleed—contained with white cards to make them pop.
# - Color scheme: Cream section background (#F6F1EC); headings in espresso (#3B2A22); CTAs in espresso with cream text for contrast.
# - Copy highlights & CTAs:
#   - Bianca: “Dual boiler control for café-level consistency at home.” CTA: “Shop Bianca”.
#   - Elizabeth: “Rapid heat-up, compact footprint, full-bodied flavor.” CTA: “Shop Elizabeth”.
#
# Section 3 – Product teaser single (MaraX spotlight)
# - Core goal/CTA: Feature a third hero product for breadth.
# - Image: PESMX02_MaraX-01.png (MaraX). Unique usage.
# - Layout: 70/30 split with large image left, tight copy right; one CTA. Rounded corners on image.
# - Edges/padding: Cream background continues for cohesion; extra top/bottom space to feel premium.
# - Color scheme: Same as Section 2 for continuity.
# - Copy & CTA: “Adaptive temperature stability for sweeter extractions.” CTA: “Shop MaraX”.
#
# Micro Divider – Visual rhythm
# - A thin espresso-colored rule to separate product content from brand story.
#
# Section 4 – About Us manifesto intro
# - Core goal/CTA: Build trust; click to learn about our brand/manufacturing ethos.
# - Images: about-us-manifesto.png as a banner-like visual (if it has graphic treatment). Use full width inside a cream/espresso block; do not overlay redundant text.
# - Layout: Centered image with matching background color block to blend edges; short one-sentence blurb below; one secondary CTA.
# - Edges/padding: Ample whitespace; image contained (not full-bleed) with rounded corners to keep hierarchy below the hero.
# - Color scheme: Background in warm cream; headline/body in charcoal; CTA in copper with dark text.
# - Copy & CTA: “We’re coffee-lovers engineering tools that last.” CTA: “Read Our Story”.
#
# Section 5 – Human touch (team portrait tile)
# - Core goal/CTA: Reinforce authenticity; optional CTA to Meet the Team.
# - Images: Max Kolb 2.webp or Melanie.webp. Choose one (Max Kolb 2.webp) to avoid repetition. Single use in a card.
# - Layout: Image left 40 / text right 60; short sentence and subtle CTA link.
# - Edges/padding: Light cream background; card with soft shadow and rounded corners.
# - Color scheme: Keep espresso text on cream; link in espresso with underline.
# - Copy & CTA: “Real baristas, real guidance—before and after you buy.” CTA: “Meet the Team”.
#
# Footer – Secondary navigation
# - Core goal/CTA: Provide Shop/Support/About quick links; keep minimal.
# - Color scheme: Espresso background, cream text; low-emphasis links.
#
# Accessibility & consistency
# - Alt text: Provide descriptive alt text for all images.
# - Button sizes: Minimum 44px height.
# - Mobile: Stack columns; maintain adequate spacing; ensure contrast meets WCAG AA.
#
# Creative techniques used
# - Image-text overlay hero with bold typography.
# - Asymmetrical 60/40 and 70/30 splits.
# - Floating product images with rounded corners.
# - Unexpected color blocks and thin brutalist divider.
#
# Copy limits
# - Each section limited to max 1–2 sentences; hero has 1 short headline + 1 subtitle as required.</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; color=&quot;#222222&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button background-color=&quot;#C69C6D&quot; color=&quot;#222222&quot; font-weight=&quot;bold&quot; border-radius=&quot;6px&quot; inner-padding=&quot;14px 22px&quot; /&gt;
#       &lt;mj-image border-radius=&quot;12px&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#       &lt;mj-column padding=&quot;0&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .eyebrow {letter-spacing: 0.1em; text-transform: uppercase; font-size: 12px; color:#8c7a70}
#       .rule {border-top:2px solid #3B2A22; width:64px; margin: 0 auto;}
#       .card {border:1px solid #e8e0d9; border-radius:16px;}
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFFFFF&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;48px 24px 56px 24px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; color=&quot;#F6F1EC&quot; font-size=&quot;36px&quot; font-weight=&quot;700&quot; padding-bottom=&quot;8px&quot;&gt;New Espresso, New Ritual.&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#F6F1EC&quot; font-size=&quot;16px&quot; padding-bottom=&quot;20px&quot;&gt;Precision-built machines for richer shots and effortless mornings.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/collections/espresso&quot; align=&quot;center&quot;&gt;Shop the Collection&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Product Teasers: Bianca + Elizabeth --&gt;
#     &lt;mj-section background-color=&quot;#F6F1EC&quot; padding=&quot;40px 24px 16px 24px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column width=&quot;60%&quot; padding=&quot;0 12px 24px 0&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: A bold, modern welcome email that spotlights the new espresso machine collection first (primary action: shop the collection), followed by a concise About Us manifesto (secondary action: read more/about page). Visual style blends clean product cutouts, full-bleed lifestyle, and asymmetry with strong contrast. Palette: espresso black, warm crema beige, stainless steel silver, accent copper. Typography: large, punchy sans-serif headers, clean sans-serif body; mix with subtle serif for subheads if desired.
#
# Section 1: Hero — New Espresso Collection (Primary CTA)
# - Core goal/CTA: Drive clicks to “Shop the New Collection.”
# - Images: Use HP-Coffee machines.webp as a full-bleed hero background (no text on image, safe for overlay). Avoid repeating this image later.
# - Layout:
#   - Full-bleed background image section for impact.
#   - Overlay headline (5–7 words) + short subtitle (10–15 words) + single primary CTA button.
#   - Center-aligned text for clarity; large, bold headline (50px+). High contrast: white text over a darkened overlay.
#   - No additional images in this section; this image carries the mood.
# - Color scheme: Background image; add a semi-transparent dark overlay for legibility. Headline/subtitle in #FFFFFF; CTA button in warm crema (#EADCC2) with espresso text (#2B2623) for strong contrast.
# - Copy/CTA highlight: Headline: “Meet Your Next Espresso Ritual.” Subtitle: “Precision-built machines engineered for café-quality crema at home.” CTA: “Shop the Collection”.
#
# Section 2: New Collection Grid — Key Models Highlight
# - Core goal/CTA: Push product-level clicks to PDPs; secondary to overall collection.
# - Images: Use three product PNGs with transparent backgrounds for a floating effect:
#   - PDP-PESBN03-LELIT-Bianca_01.png (Bianca)
#   - PESMX02_MaraX-01.png (MaraX)
#   - PDP-PESEL01-Elizabeth-01.png (Elizabeth)
#   Each used once; do not reuse elsewhere.
# - Layout:
#   - Three columns on desktop (stack on mobile). Each features a floating product image, a tight benefit sentence, and a small text link CTA.
#   - Use subtle drop shadows and rounded corners around image containers to make products “float.”
#   - Asymmetry: slightly different background tints per column to create rhythm (very light neutrals from palette).
#   - Keep copy to a single sentence per product; use text links rather than multiple buttons to avoid competing with hero CTA.
# - Color scheme: Section background in off-white (#FAF7F2). Column backgrounds: very light tonal blocks (#FFFFFF, #F5F2EC, #FFFDF8). Headlines in espresso black (#1E1B18), links in deep espresso (#2B2623) with underline.
# - Copy/CTA highlight:
#   - Bianca: “Dual boilers, flow control—dial in like a pro.” Link: “Shop Bianca →”
#   - MaraX: “Consistent temperature, compact footprint, big flavor.” Link: “Shop MaraX →”
#   - Elizabeth: “Rapid heat-up with silky microfoam, daily.” Link: “Shop Elizabeth →”
#
# Section 3: Testimonial/Founder Note Visual Break (Optional micro-social proof)
# - Core goal/CTA: Soft credibility; no extra CTA (avoid CTA overload). This primes the About Us below.
# - Images: Use Melanie.webp (portrait) for a human touch. Use once, small.
# - Layout:
#   - 70/30 split: 30% portrait on the left with rounded corners; 70% text on right with a one-sentence quote.
#   - Keep compact; acts as a spacer with value.
# - Color scheme: Cream background (#F8F3EA). Text in near-black; subtle border/divider in #E6E0D6.
# - Copy highlight: “The crema and control changed my mornings.” —Melanie
#
# Section 4: About Us — Manifesto Banner (Secondary CTA)
# - Core goal/CTA: Drive to About page/brand story; build trust.
# - Images: Use about-us-manifesto.png as a full-width banner. If the image contains notable graphical elements but no text, we can overlay brief copy; if it contains significant embedded text, we won’t add overlapping text per rules. Treat it as a banner; add textual block below with CTA. We will not place a second CTA inside the image; the button will be below unless the image has its own CTA (it doesn’t).
# - Layout:
#   - Full-width image with edge-to-edge display.
#   - Below the image: a short, bold line plus one-sentence subcopy and a secondary button.
#   - Maintain breathing room with generous padding.
# - Color scheme: Section background picks a dominant color sampled from the banner (assume light neutral). Text in espresso black; button in espresso black with white text for contrast.
# - Copy/CTA highlight:
#   - Header: “Built by Coffee People.”
#   - Subcopy: “We test, tune, and support every machine so you pull better shots.”
#   - CTA: “About Our Craft”.
#
# Section 5: Footer — Lightweight Utility
# - Core goal/CTA: Present support/contact quickly; no primary CTA.
# - Images: None (save imagery weight). Keep it clean.
# - Layout: Simple two-column for contact/support and social text links.
# - Color scheme: Very light background; small, accessible type; strong contrast links.
# - Copy highlight: “Questions? Our coffee experts can help.” Links: Support, Contact, Instagram.
#
# Accessibility & cohesion notes
# - Alt text on all images.
# - Sufficient color contrast for text and buttons.
# - Large tappable CTA areas; one primary CTA near top.
# - Mobile stacking with comfortable spacing.
#
# Uniqueness & brand fit
# - Bold, full-bleed lifestyle hero; floating product cutouts; asymmetrical testimonial; manifesto banner. Concise, powerful copy with a calm premium palette.
# </div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; color=&quot;#1E1B18&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button font-weight=&quot;700&quot; background-color=&quot;#EADCC2&quot; color=&quot;#2B2623&quot; border-radius=&quot;6px&quot; padding=&quot;16px 28px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .shadow { box-shadow: 0 10px 30px rgba(0,0,0,0.08); border-radius: 14px; }
#       .rounded { border-radius: 14px; }
#       .small-link a { color:#2B2623 !important; text-decoration: underline !important; font-weight:600; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFFFFF&quot;&gt;
#     &lt;!-- Hero: New Collection --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;80px 24px&quot; text-align=&quot;center&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-wrapper padding=&quot;0&quot;&gt;
#           &lt;mj-text font-size=&quot;52px&quot; font-weight=&quot;800&quot; color=&quot;#FFFFFF&quot; padding=&quot;8px&quot;&gt;Meet Your Next Espresso Ritual&lt;/mj-text&gt;
#           &lt;mj-text font-size=&quot;18px&quot; color=&quot;#FFFFFF&quot; padding=&quot;8px&quot;&gt;Precision-built machines engineered for café-quality crema at home.&lt;/mj-text&gt;
#           &lt;mj-button href=&quot;#shop-collection&quot; align=&quot;center&quot; padding-top=&quot;20px&quot;&gt;Shop the Collection&lt;/mj-button&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Spacer --&gt;
#     &lt;mj-section padding=&quot;24px&quot;&gt;&lt;/mj-section&gt;
#
#     &lt;!-- New Collection Grid --&gt;
#     &lt;mj-section background-color=&quot;#FAF7F2&quot; padding=&quot;24px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&qu
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: A sensory, editorial-style recipe email with a dramatic hero that uses a full-bleed food image as background with bold overlaid typography, followed by a clean, scannable recipe block using asymmetry and color blocking. Secondary note encourages sign-ups for text alerts using a contrasting coupon-style card.
#
# Brand palette assumptions: Deep navy (#0B2239), seafoam (#CFE8E0), warm off-white (#F7F5F2), accent coral (#FF6A5E). Typography mix: Bold serif for headlines, clean sans for body. High contrast maintained.
#
# Section 1: Hero — Chilean Seabass recipe
# - Core goal/CTA: Get readers to click to view the full Chilean Seabass recipe.
# - Images: qpIEKrPysdDZ.jpg (wide, food-friendly ratio), used once.
# - Image layout: Full-width, full-bleed background image with overlaid text and a single primary CTA button. No text embedded on the image file, so overlay is allowed. Add generous padding for readability; keep button centered. No duplicate CTAs in this section.
# - Layout choice: One-column mj-section with background image, large headline (5–7 words) and a 10–15 word subtitle, then a prominent button. Use a subtle dark-to-transparent overlay via background color on columns for text legibility.
# - Color scheme: White text over image; button in coral (#FF6A5E) with white text; subtle shadow to lift.
# - Copy highlight: Punchy headline naming the dish; subtitle teases technique + flavor payoff. CTA: “Cook The Recipe”.
#
# Section 2: Recipe tease — Ingredients + key benefit (asymmetrical split)
# - Core goal/CTA: Secondary nudge to view the recipe with a skim of essentials.
# - Images: BL-jOWEdyIYp.jpg (supporting kitchen/ingredient vibe), used once.
# - Image layout: 60/40 split; 40% image with rounded corners and slight overlap feel; 60% text on a seafoam background. Image displayed with inner padding so it floats.
# - Color scheme: Seafoam panel (#CFE8E0) with navy text; subtle off-white section background (#F7F5F2) to differentiate from hero.
# - Copy highlight: One sentence benefit-focused line; bullet-style micro list of 3 key items (kept concise). CTA button: “See Full Method”.
#
# Section 3: Chef tip micro-block
# - Core goal/CTA: Build authority and entice clicks; small inline link.
# - Images: None (to avoid repetition and keep the rhythm varied).
# - Layout: Narrow band with a left border accent in coral. Short, single sentence.
# - Color scheme: Off-white background; navy text; coral border.
# - Copy highlight: High-heat sear + butter baste tip; inline link “Read tip”.
#
# Section 4: Text alerts signup — coupon-style card
# - Core goal/CTA: Get readers to opt in to SMS alerts.
# - Images: d8FtbX8GvJh4.png as a thin decorative divider above the card; NoUihF8gfITs.png as a subtle icon block inside the card (not required; optional tiny accent). Avoid crowding; use only one decorative image (use d8FtbX8GvJh4.png). Do not reuse images from earlier sections.
# - Image layout: The divider image spans content width with padding; the signup card is text-only with dashed border to evoke a coupon. No image-based CTA.
# - Color scheme: Paper-like warm off-white background (#FFF9F0) for the card, navy text, coral dashed border. CTA button in navy with white text.
# - Copy highlight: One compact sentence promising alerts; CTA: “Get Text Alerts”.
#
# Section 5: Footer
# - Core goal/CTA: Standard info; subdued.
# - Images: NMKa-PpjGOLD.png as a minimalist line/brand mark footer rule.
# - Layout: Centered, small.
# - Color scheme: Deep navy background, muted text in light gray for contrast.
#
# Accessibility and cohesion
# - All images get alt text.
# - Sufficient contrast on all buttons and overlays.
# - Buttons large and tappable on mobile.
# - Spacing rhythm: 48px hero padding, 32px content padding, 24px inter-element spacing.
#
# Copy per section (adhering to brevity)
# - Hero headline: “Chilean Seabass, Restaurant-Ready”
# - Hero subtitle: “Buttery, crisp-edged fillets in 20 minutes—pan-seared and finished with lemon.”
# - Hero CTA: “Cook The Recipe”
# - Recipe tease sentence: “Simple technique, big flavor—sear, baste, finish.”
# - Micro list (concise): “Chilean seabass • Lemon butter • Fresh herbs”
# - Tease CTA: “See Full Method”
# - Chef tip: “Pro tip: Pat fish dry and baste with foaming butter for glassy, crisp edges.” (Inline link: “Read tip”)
# - SMS blurb: “Get text alerts for fresh recipes, drops, and limited-time inspo.”
# - SMS CTA: “Get Text Alerts”</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-text font-family=&quot;Helvetica, Arial, sans-serif&quot; color=&quot;#0B2239&quot; font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button font-family=&quot;Helvetica, Arial, sans-serif&quot; background-color=&quot;#FF6A5E&quot; color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; inner-padding=&quot;14px 24px&quot; border-radius=&quot;6px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .shadow-soft { box-shadow: 0 8px 24px rgba(0,0,0,0.12); }
#       .rounded { border-radius: 12px; overflow: hidden; }
#       .coupon { border: 2px dashed #FF6A5E; border-radius: 10px; background:#FFF9F0; }
#       .tip { border-left:4px solid #FF6A5E; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#F7F5F2&quot;&gt;
#
#     &lt;!-- Hero: Chilean Seabass --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; background-url=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;0&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(11,34,57,0.35)&quot; padding=&quot;48px 24px 56px 24px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;34px&quot; font-weight=&quot;700&quot; font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; padding=&quot;8px 0 4px 0&quot;&gt;Chilean Seabass, Restaurant-Ready&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; padding=&quot;0 16px 20px 16px&quot;&gt;Buttery, crisp-edged fillets in 20 minutes—pan-seared and finished with lemon.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/recipes/chilean-seabass&quot; align=&quot;center&quot;&gt;Cook The Recipe&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe Tease: Asymmetrical 60/40 --&gt;
#     &lt;mj-section background-color=&quot;#F7F5F2&quot; padding=&quot;32px 24px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column width=&quot;60%&quot; background-color=&quot;#CFE8E0&quot; padding=&quot;24px&quot; css-class=&quot;shadow-soft rounded&quot;&gt;
#           &lt;mj-text font-size=&quot;18px&quot; font-weight=&quot;700&quot; font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; padding=&quot;0 0 8px 0&quot;&gt;Weeknight-easy, chef-level finish&lt;/mj-text&gt;
#           &lt;mj-text padding=&quot;0 0 12px 0&quot;&gt;Simple technique, big flavor—sear, baste, finish.&lt;/mj-text&gt;
#           &lt;mj-text padding=&quot;0 0 16px 0&quot;&gt;• Chilean seabass • Lemon butter • Fresh herbs&lt;/mj-text&gt;
#           &lt;mj-button background-color=&quot;#0B2239&quot; href=&quot;https://example.com/recipes/chilean-seabass#method&quot;&gt;See Full Method&lt;/mj-button&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;40%&quot; padding=&quot;0 0 0 16px&quot;&gt;
#           &lt;mj-image src=&quot;
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: A recipe-forward email centered on Chilean Sea Bass, presented as a beautifully minimal full-bleed hero recipe card with overlaid headline and a single primary CTA. Below, a lean note invites readers to sign up for SMS alerts.
#
# Brand tone: Clean, modern, food-centric. Use bold typographic hierarchy, generous whitespace, and restrained color with one accent. Leverage a full-bleed image header for impact, then a structured recipe snippet card with asymmetry.
#
# Color palette:
# - Background: soft off-white (#FAFAF8) for body sections to feel culinary and airy.
# - Accent: deep slate/navy (#1C2B2D) for headlines and buttons; secondary accent warm olive (#97A37A) for subheads/dividers.
# - Text on images: pure white for contrast over darker photography areas; use subtle black overlay for readability.
#
# Typography mix:
# - Headlines: serif, bold, large for editorial vibe (fallback: Georgia/Times).
# - Body/CTAs: clean sans-serif (Helvetica/Arial) for readability.
#
# Images mapping and layout decisions:
# 1) Hero full-bleed recipe teaser
# - Core goal/CTA: Drive clicks to view the Chilean Sea Bass recipe. Primary CTA: "Get the Recipe".
# - Image: BL-jOWEdyIYp.jpg (640x360). Use as a full-bleed background in the hero with text overlay. No text exists on image, so safe to overlay headline + subtitle. Add a semi-transparent dark overlay via background color + padding to ensure readability.
# - Layout: Full-width mj-section with background-url, tall padding to feel immersive; centered overlay copy. No extra button if we place a centered button—ok to include since image has no text/CTA. CTA as a single primary button.
# - Color scheme: White text on darkened image; button in warm olive with white text for contrast.
# - Copy highlight: Punchy headline (5–7 words) + short subtitle focusing on buttery, flaky, weeknight-easy idea.
#
# 2) Recipe details card (asymmetrical split)
# - Core goal/CTA: Secondary encouragement to view full recipe by teasing key benefits and quick prep cues. Include a secondary button "Cook It Tonight".
# - Image: qpIEKrPysdDZ.jpg (640x360) displayed with rounded corners and slight shadow, contained within the left column (60/40 layout). This is a different angle/food texture to avoid repetition. No overlay text; add caption in text column.
# - Layout: 60/40 split (image 60%), text 40% on a light card with subtle border. Use unexpected offset: image flush left with edge-to-edge inside its column; text padded generously.
# - Color scheme: Card background white (#FFFFFF) on off-white section; olive subheads; navy body text.
# - Copy highlight: One benefit-driven sentence about crispy skin and silky center; bullet-like short line for prep time. CTA button minimal.
#
# 3) Micro tip strip (contextual add-on)
# - Core goal/CTA: Increase perceived value by giving a tiny tip. No separate CTA; supports the main action.
# - Image: d8FtbX8GvJh4.png (600x100) used as a thin divider-style accent banner full-width to break rhythm; no text overlay.
# - Layout: Full-width separator with edge-to-edge; below it, a single-line tip text. Keep it minimal to obey copy constraints.
# - Color scheme: Divider sits on off-white; keep text in navy.
# - Copy highlight: One crisp tip about pat-dry and hot pan sear.
#
# 4) SMS alerts sign-up note
# - Core goal/CTA: Encourage sign-up for text alerts. CTA: "Text Me Updates".
# - Image: NoUihF8gfITs.png (640x596) as a subtle background pattern behind a compact card, lightly faded for cohesion. No overlayed text on the image originally, so safe to overlay; ensure high contrast by adding a semi-opaque white card atop.
# - Layout: Centered small card with iconless, concise copy and one button. Rounded corners; dashed border not used (no promo code). Keep hierarchy understated since primary focus remains recipe.
# - Color scheme: White card with olive border; navy text; olive button.
# - Copy highlight: One sentence promising early access to recipes, drops, and limited promos.
#
# 5) Footer logo strip
# - Core goal/CTA: None; brand closure.
# - Image: NMKa-PpjGOLD.png (640x62) used as a slim brand bar near the footer.
# - Layout: Centered image with padding; no text overlay.
# - Color scheme: Neutral off-white background.
#
# Accessibility/contrast:
# - Ensure buttons are WCAG-compliant: olive #8AA36B with white text; hover not applicable in email but align with brand.
# - All images include alt text.
#
# CTAs summary:
# - Primary: Get the Recipe (hero)
# - Secondary: Cook It Tonight (details card)
# - Tertiary: Text Me Updates (SMS note)
#
# Creative techniques used:
# - Image-text overlay hero with strong contrast.
# - Asymmetrical 60/40 product layout with rounded image.
# - Full-width graphic divider to create rhythm.
# - Subtle background image for SMS card.
# - Bold typographic mix and unexpected whitespace.
# </div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; color=&quot;#1C2B2D&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button background-color=&quot;#8AA36B&quot; color=&quot;#FFFFFF&quot; font-weight=&quot;700&quot; inner-padding=&quot;14px 22px&quot; border-radius=&quot;6px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#       &lt;mj-image padding=&quot;0px&quot; border-radius=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .card { box-shadow: 0 6px 24px rgba(0,0,0,0.08); border-radius: 14px; }
#       .subtle-border { border: 1px solid #E7E7E0; border-radius: 14px; }
#       .rounded { border-radius: 14px; }
#       .overline { letter-spacing: 0.08em; text-transform: uppercase; font-size: 12px; color: #97A37A; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FAFAF8&quot;&gt;
#
#     &lt;!-- Hero: Full-bleed recipe background --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; background-url=&quot;/uploads/BL-jOWEdyIYp.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;60px 20px 80px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot; background-color=&quot;rgba(0,0,0,0.35)&quot; border-radius=&quot;16px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; color=&quot;#FFFFFF&quot; font-size=&quot;40px&quot; font-weight=&quot;700&quot; padding=&quot;20px 10px 6px&quot;&gt;Chilean Sea Bass, Simplified&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; padding=&quot;0 16px 18px&quot;&gt;Buttery, flaky, pan-seared perfection—ready in under 20 minutes.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/recipes/chilean-sea-bass&quot; align=&quot;center&quot;&gt;Get the Recipe&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe details card: 60/40 split --&gt;
#     &lt;mj-section background-color=&quot;#FAFAF8&quot; padding=&quot;28px 20px 6px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-spacer height=&quot;8px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#FAFAF8&quot; padding=&quot;0 20px 32px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card subtle-border&quot; background-color=&quot;#FFFFFF&quot;&gt;
#           &lt;mj-section padding=&quot;0&quot; background-color=&quot;#FFFFFF&
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: A bold, community-forward invite for an annual “Create-a-Quilt” event in Portsmouth, NH. Visual rhythm mixes full-bleed texture, asymmetrical blocks, and clean CTAs. Primary CTA: Register/Sign Up. Secondary: View schedule, Volunteer, See past quilts.
#
# Section 1 – Hero: “Create-a-Quilt 2025” Invite
# - Core goal/CTA: Drive registrations (primary CTA: Register Now).
# - Images: Use q1rNLeA5MGW4.png as a full-bleed background (broad, cinematic ratio) with large, high-contrast headline overlay. No text on image, so safe to overlay.
# - Layout thoughts: Full-width background section with centered headline and subhead, bold typography (serif headline + sans body). One primary CTA button centered. Add subtle overlay color for readability.
# - Color scheme: Warm craft-inspired palette: deep navy text over a slightly darkened image; primary button in warm coral/red to pop; supporting text white. Ensure contrast with a semi-transparent dark overlay on the background.
# - Copy highlights: Headline: “Create • Quilt • Community”. Subtitle: “Join Portsmouth’s annual quilting day—novice to pro, everyone’s in.” CTA: “Register Now”.
#
# Section 2 – What to Expect (Workshops + Community)
# - Core goal/CTA: View event schedule (secondary CTA).
# - Images: IE9az4JoTkMu.png (square) featured as left 60% image; this can represent people and materials (generic placeholder). No overlay text on image; keep clean.
# - Layout thoughts: 60/40 split (image left, text right). Rounded image corners. Text right with short sentence and “View Schedule” button.
# - Color scheme: Light warm background (cream), dark navy text; button in forest green to differentiate from hero. Edge padding around image for air.
# - Copy highlights: One sentence on hands-on sessions and friendly help. CTA: “View Schedule”.
#
# Section 3 – Quilt Design Challenge (New Patterns)
# - Core goal/CTA: Encourage sign-ups for the design challenge (register included).
# - Images: 6w0BvmNX9G7t.png as a banner within the section (full-width inside container, not edge-to-edge) to show a bold visual break. No overlay text; keep separate CTA in text block.
# - Layout thoughts: Image on top with tight rounded edges, followed by centered text and a CTA. Use unexpected color block behind text (soft teal) for contrast.
# - Color scheme: Soft teal block, charcoal text, coral CTA for continuity.
# - Copy highlights: “Submit your block, win fabric prizes.” CTA: “Enter the Challenge”.
#
# Section 4 – Volunteer + Community Table
# - Core goal/CTA: Recruit volunteers.
# - Images: KcswBqLO-Ff_.png and N4807TOO3CUx.png as two side-by-side squares (50/50) with rounded corners; no text overlays.
# - Layout thoughts: Two-column grid; headline above columns, small copy below headline, one CTA under the columns spanning full width. Keep columns with slight shadow or border to add structure.
# - Color scheme: Very light gray background; buttons in navy; text in near-black. Subtle borders in #EAEAEA around images for cohesion.
# - Copy highlights: “Help set up, guide stations, and cheer makers on.” CTA: “Volunteer Sign-Up”.
#
# Section 5 – Past Quilts Gallery (Inspiration)
# - Core goal/CTA: Drive clicks to gallery page.
# - Images: 7oP1eqIoGS-J.png, hA2OiBty-zz0.png, ZWonHtct7o2E.png arranged in a broken grid: 70/30 split with two stacked small images on the narrow column and one large image in the wide column.
# - Layout thoughts: Asymmetrical layout: left 70% large image (full height), right 30% stacked images with tight gutters. No overlay text. CTA button centered below grid.
# - Color scheme: White background to let images shine; button in green; text in charcoal.
# - Copy highlights: “See last year’s show-stoppers.” CTA: “View Gallery”.
#
# Section 6 – Location + Date (Portsmouth, NH)
# - Core goal/CTA: Add to calendar/get directions.
# - Images: bHyb-RbQe-aY.jpg as a thin full-width divider banner (harbor-esque header vibe). No text overlay to avoid repetition; keep the copy separate below.
# - Layout thoughts: Full-width image strip as a visual separator, then a compact text block with two inline CTAs: “Add to Calendar” and “Get Directions”.
# - Color scheme: Navy background for the text block under the image; white text; buttons: one white outline, one solid white with navy text for contrast pairing.
# - Copy highlights: “Saturday, May 10 • 10am–4pm • Portsmouth NH”. CTAs: “Add to Calendar”, “Get Directions”.
#
# Section 7 – Footer (FAQs + Contact)
# - Core goal/CTA: FAQ link and contact.
# - Images: None.
# - Layout thoughts: Simple two-column text links on light background. Small social icons replaced by text links to keep minimal. Extra spacing.
# - Color scheme: Light cream background, muted gray text, links in navy. Keep contrast accessible.
# - Copy highlights: “Questions? Email… • FAQs • Refund policy.”
#
# Accessibility & cohesion notes:
# - Alt text included for all images. Maintain generous line-height and large buttons. Buttons have clear, concise labels. Consistent rounded corners theme for images and buttons ties sections together.
# </div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-text font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; color=&quot;#0F172A&quot; line-height=&quot;1.4&quot; /&gt;
#       &lt;mj-button font-family=&quot;Inter, -apple-system, BlinkMacSystemFont, &#x27;Segoe UI&#x27;, Roboto, Arial, sans-serif&quot; background-color=&quot;#E34D4D&quot; color=&quot;#FFFFFF&quot; inner-padding=&quot;14px 22px&quot; border-radius=&quot;24px&quot; font-weight=&quot;700&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#       &lt;mj-column padding=&quot;0&quot; /&gt;
#       &lt;mj-image padding=&quot;0&quot; border-radius=&quot;16px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&amp;display=swap&quot; /&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFFFFF&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;60px 24px&quot; text-align=&quot;center&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-wrapper background-color=&quot;rgba(0,0,0,0.35)&quot; padding=&quot;24px&quot; border-radius=&quot;20px&quot;&gt;
#           &lt;mj-text font-family=&quot;Georgia, &#x27;Times New Roman&#x27;, serif&quot; color=&quot;#FFFFFF&quot; font-size=&quot;46px&quot; font-weight=&quot;700&quot; padding-bottom=&quot;8px&quot;&gt;Create • Quilt • Community&lt;/mj-text&gt;
#           &lt;mj-text font-family=&quot;Inter, Arial, sans-serif&quot; color=&quot;#FFFFFF&quot; font-size=&quot;18px&quot; padding-bottom=&quot;20px&quot;&gt;Join Portsmouth’s annual quilting day—novice to pro, everyone’s in.&lt;/mj-text&gt;
#           &lt;mj-button href=&quot;#register&quot; background-color=&quot;#E34D4D&quot;&gt;Register Now&lt;/mj-button&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Expect: Workshops --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F0&quot; padding=&quot;36px 24px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column width=&quot;60%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; alt=&quot;Hands arranging quilting fabric and tools&quot; border-radius=&quot;16px&quot; padding=&quot;0&quot; /&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;40%&quot;
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Overall concept: Energetic, community-forward invitation for an annual “Create-a-Quilt” event in Portsmouth, NH. Emphasis on inclusivity (novice to advanced), hands-on making, sign-up urgency, schedule highlights, and showcasing last year’s quilts. Brand vibe: cozy-meets-modern craft—warm neutrals with bright accent blocks inspired by thread spools and quilt swatches.
#
# Brand palette suggestion per section: warm cream (#FAF7F2), deep navy (#0E2A3A), coral (#FF6B6B), goldenrod (#F6B840), moss green (#2C6E49), slate gray (#5C6B73). Keep text high-contrast (navy or near-black on light backgrounds; white on deep/navy overlays).
#
# Section 1: Hero – Full-bleed invitation
# - Core goal/CTA: Primary CTA: Register Now (ticket/signup page).
# - Images: q1rNLeA5MGW4.png (1280x730) as full-bleed background; no overlay text present, works well for bold header overlay. Avoid repeating any embedded text (there is none).
# - Layout approach: Full-bleed background section with centered headline + subtitle + one prominent button. Add a subtle color overlay via a semi-transparent background color on text container if needed for readability. No additional images here. Edges should go to full width for impact.
# - Color scheme: Overlay text in white on a slightly darkened image (use deep navy button with white text). Keep it clean and bold.
# - Copy/CTA focus: Headline 5–7 words; subtitle 10–15 words; Button: Register Now.
#
# Section 2: Why join (Novice to Advanced, inclusive)
# - Core goal/CTA: Secondary CTA: See Sessions (link to agenda/workshops page).
# - Images: IE9az4JoTkMu.png (1080x1080) cropped with rounded corners as a quilt-in-progress mood image inside a 60/40 split; ensure no text overlay on the image itself.
# - Layout approach: Asymmetrical 60/40: left text on cream background; right image with rounded corners, slight shadow, contained with padding for breathing room.
# - Color scheme: Cream background (#FAF7F2), navy headline, slate body, coral accent underline/divider. CTA button coral with white text.
# - Copy/CTA focus: One sentence emphasizing “all skill levels welcome” and hands-on guidance; Button: See Sessions.
#
# Section 3: Schedule snapshot (date/time/location)
# - Core goal/CTA: CTA: Add to Calendar (link to .ics or calendar page).
# - Images: bHyb-RbQe-aY.jpg (1013x283) as a slim banner divider at top of section; it contains no text; use as a visual thread motif. Do not overlay more text on the image area; text sits below.
# - Layout approach: Image banner full-width with padding, then centered text blocks with bold date/time/location in a compact format; single inline CTA button.
# - Color scheme: White section with navy text; goldenrod button for contrast.
# - Copy/CTA focus: One tight line with date/time/place; Button: Add to Calendar.
#
# Section 4: Gallery tease – Past quilts
# - Core goal/CTA: CTA: View Gallery (to inspiration page). Encourage scrolling curiosity.
# - Images: Use a 3-up broken grid collage with: KcswBqLO-Ff_.png, N4807TOO3CUx.png, hA2OiBty-zz0.png. Each appears once, rounded corners, slight overlapping margins for a broken-grid feel. No text overlays.
# - Layout approach: Split-screen: left narrow column for short copy; right wider column with three floating images staggered (top-left, center-right, bottom-left) using padding/margins. Maintain accessible spacing.
# - Color scheme: Soft moss green background for the section (#E8F0EB) to harmonize with textiles; navy copy; white CTA with moss text and navy border.
# - Copy/CTA focus: Single sentence about last year’s standout quilts; Button: View Gallery.
#
# Section 5: What to bring + provided
# - Core goal/CTA: CTA: See Supply List (PDF or page). Clarify that materials are available for novices.
# - Images: ZWonHtct7o2E.png (404x511) small icon-like image in a left 30% column to add visual cue (spools/tools vibe). Ensure no text overlay on image.
# - Layout approach: 30/70 columns. Left: image centered with a circle background. Right: concise single sentence and button stacked. Extra white space to keep airy.
# - Color scheme: Light slate background (#F4F7F9), navy text, coral button.
# - Copy/CTA focus: Sentence: “We supply fabrics and stations; bring your favorites if you like.” Button: See Supply List.
#
# Section 6: Volunteer & sponsor callout
# - Core goal/CTA: Dual CTAs: Volunteer Sign-Up and Sponsor the Event. Keep them side-by-side secondary CTAs.
# - Images: EZItMmj9aQSE.png (507x514) as a small sticker-style floating image between headline and buttons; rounded with a thin navy border. Use once.
# - Layout approach: Centered content block with bold headline and two outlined buttons. Lots of white space.
# - Color scheme: White background, navy text, outlined buttons: one moss outline, one goldenrod outline.
# - Copy/CTA focus: One sentence inviting helpers and local businesses.
#
# Section 7: Footer – Location map tease + contact
# - Core goal/CTA: CTA: Get Directions (maps link). Secondary: Reply-to contact.
# - Images: 7oP1eqIoGS-J.png (935x568) as a narrow, full-width image bar with rounded top corners; no text overlay on image.
# - Layout approach: Image bar followed by concise contact line and social icons placeholders (text links). Keep minimal.
# - Color scheme: Navy background for footer with white text; directions button in goldenrod.
# - Copy/CTA focus: One-line address and hospitality phrase; Button: Get Directions.
#
# Notes on image usage: Each selected image is used only once: q1rNLeA5MGW4.png (Hero), IE9az4JoTkMu.png (Why join), bHyb-RbQe-aY.jpg (Schedule banner), KcswBqLO-Ff_.png + N4807TOO3CUx.png + hA2OiBty-zz0.png (Gallery), ZWonHtct7o2E.png (Supplies), EZItMmj9aQSE.png (Volunteer/Sponsor sticker), 7oP1eqIoGS-J.png (Footer). Remaining images not used: 6w0BvmNX9G7t.png, N/A.
#
# Typography pairing: Headings in a friendly slab/serif (e.g., 'Sentinel' or 'Roboto Slab' substitute: Georgia), body in a clean sans-serif (e.g., Inter/Arial). Use large, bold hero headline (50–56px) and compact body text.
#
# Accessibility: Alt text for all images; buttons at least 44px height; color contrast AAA where feasible.
#
# Copy per section (strict brevity):
# - Hero: Headline: Quilt together, Portsmouth! Subtitle: Join novices and pros for a day of bold, beautiful making. Button: Register Now.
# - Why join: Copy: Hands-on stations, friendly mentors—come stitch at your level. Button: See Sessions.
# - Schedule: Copy: Saturday, Oct 19 • 10–4 • Portsmouth, NH. Button: Add to Calendar.
# - Gallery: Copy: Peek last year’s showstoppers and fresh patterns. Button: View Gallery.
# - Supplies: Copy: We provide fabrics and tools—bring favorites if you like. Button: See Supply List.
# - Volunteer/Sponsor: Copy: Lend a hand or power the event—locals make it shine. Buttons: Volunteer Sign-Up; Sponsor the Event.
# - Footer: Copy: 123 Market St, Portsmouth NH • Community Arts Hall. Button: Get Directions.</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Arial, Helvetica, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#0E2A3A&quot; font-size=&quot;16px&quot; line-height=&quot;1.4&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#       &lt;mj-button font-weight=&quot;700&quot; inner-padding=&quot;14px 24px&quot; border-radius=&quot;6px&quot; /&gt;
#       &lt;mj-image padding=&quot;0&quot; border-radius=&quot;0&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .rounded { border-radius: 14px !important; }
#       .circle { border-radius: 999px !important; }
#       .shadow

# %%
## TESTING CLAUDE OPUS

for test_case, prompt in [
    ['coffee', 'customer welcome email. start with introducing our new collection of espresso machines. Then add more about us below that.'], 
    ['seafood', 'focus of the email should be the chilean seabass recipe section. Come up with an interesting way to show this. Then include a note to sign up for text alerts below that'],
    ['craft store','annual create a quilt event. Bringing together novice and advanced quilters from around Portsmouth NH to create beautiful new designs.']
]:
    for _ in range(2): 
        output_text = test_prompts.generate_emails_from_prompt(
            system_prompt=EMAIL_SYSTEM_PROMPT_MAIN, 
            test_case=test_case,
            creative_brief=prompt,
            has_plan_step_in_output=True,
            provider="anthropic"
        )
# Out:
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">This welcome email will have two main parts:
#
# PART 1 - NEW COLLECTION HERO:
# - Core goal/CTA: Get customers excited about our espresso machine collection and drive them to explore products
# - Images: I'll use PDP-PESBN03-LELIT-Bianca_01.png as the hero image - it's a clean product shot that will work well as a focal point
# - Layout: Full-width hero section with the machine image prominently displayed. Since this is a clean product shot with no text overlay, I'll add a bold headline and minimal supporting text. The image will be displayed with some padding to let it breathe
# - Color scheme: Clean white background to match the product photography style, with black text for strong contrast. A bold colored CTA button (perhaps a warm brown to evoke coffee) to draw the eye
# - Copy focus: Welcome message tied to the excitement of starting their espresso journey, with emphasis on the new collection
#
# PART 2 - ABOUT US GRID:
# - Core goal/CTA: Build trust and connection with the brand story
# - Images: I'll use a combination - HP-Coffee machines.webp showing our range, Max Kolb 2.webp for a human element showing expertise/craftsmanship, and about-us-manifesto.png for our values
# - Layout: Asymmetrical 3-column layout transitioning to a 60/40 split. This creates visual interest while showcasing different aspects of our brand
# - Color scheme: Warm, inviting tones - perhaps a light coffee/cream background color to differentiate from the hero section
# - Copy focus: Brief, punchy statements about quality, expertise, and passion - letting the images tell most of the story
#
# Overall approach: Start clean and product-focused, then warm up with human elements and brand story. Use plenty of whitespace and let the images be the stars.</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .headline-serif { font-family: Georgia, serif !important; }
#       .cta-rounded { border-radius: 30px !important; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#ffffff&quot;&gt;
#
#     &lt;!-- Hero Section --&gt;
#     &lt;mj-section padding=&quot;40px 20px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;42px&quot; font-weight=&quot;300&quot; color=&quot;#1a1a1a&quot; align=&quot;center&quot; css-class=&quot;headline-serif&quot; padding-bottom=&quot;15px&quot;&gt;
#           Welcome to Exceptional Espresso
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;0px 40px 30px 40px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; width=&quot;500px&quot; alt=&quot;Lelit Bianca Espresso Machine&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#666666&quot; font-size=&quot;18px&quot; padding=&quot;20px 0 25px 0&quot;&gt;
#           Your journey starts with our newest machines.
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#8B4513&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; padding=&quot;0&quot; inner-padding=&quot;15px 45px&quot; border-radius=&quot;30px&quot; css-class=&quot;cta-rounded&quot; href=&quot;#&quot;&gt;
#           EXPLORE COLLECTION →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Divider --&gt;
#     &lt;mj-section padding=&quot;30px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-color=&quot;#f0f0f0&quot; border-width=&quot;1px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us Section --&gt;
#     &lt;mj-section background-color=&quot;#faf8f5&quot; padding=&quot;40px 20px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;32px&quot; color=&quot;#1a1a1a&quot; align=&quot;center&quot; font-weight=&quot;300&quot; css-class=&quot;headline-serif&quot;&gt;
#           Crafted with Obsession
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- 3-Column Asymmetric Grid --&gt;
#     &lt;mj-section background-color=&quot;#faf8f5&quot; padding=&quot;20px 10px&quot;&gt;
#       &lt;mj-column width=&quot;35%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/Max Kolb 2.webp&quot; border-radius=&quot;8px&quot; alt=&quot;Master craftsman at work&quot; /&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#333333&quot; padding-top=&quot;10px&quot; font-weight=&quot;600&quot;&gt;
#           EXPERTISE
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;
#           20+ years perfecting every detail
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;40%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/HP-Coffee machines.webp&quot; border-radius=&quot;8px&quot; alt=&quot;Our espresso machine collection&quot; /&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#333333&quot; padding-top=&quot;10px&quot; font-weight=&quot;600&quot;&gt;
#           SELECTION
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;
#           Curated for the discerning home barista
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;25%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; alt=&quot;Our manifesto&quot; /&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#333333&quot; padding-top=&quot;10px&quot; font-weight=&quot;600&quot;&gt;
#           PASSION
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;
#           Coffee is life ☕
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#faf8f5&quot; padding=&quot;30px 20px 40px 20px&quot;&gt;
#       &lt;gj-column&gt;
#         &lt;mj-button background-color=&quot;transparent&quot; color=&quot;#8B4513&quot; font-size=&quot;15px&quot; font-weight=&quot;600&quot; border=&quot;2px solid #8B4513&quot; inner-padding=&quot;12px 35px&quot; border-radius=&quot;25px&quot; href=&quot;#&quot;&gt;
#           LEARN OUR STORY
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/coffee/2025-08-26 13:14:55.108306/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">This welcome email will have two main parts: introducing the new espresso machine collection and sharing about the company.
#
# Part 1 - New Collection Introduction:
# - Core goal/CTA: Drive traffic to browse the new espresso machine collection
# - Images to use: I'll create a hero section with the Bianca machine (DNA-Bianca.webp) as it's a striking square image that will work well as a full-width hero. Then I'll showcase 4 machines in a grid: PDP-PESBN03-LELIT-Bianca_01.png, PDP-PESEL01-Elizabeth-01.png, PESKA01+-+Kate.png, and PESMX02_MaraX-01.png
# - Layout: Full-bleed hero image with text overlay on DNA-Bianca.webp (since it has no text on it), followed by an asymmetrical 2-column grid showcasing the machines with minimal text
# - Color scheme: Dark espresso brown backgrounds to make the metallic machines pop, with cream/white text for contrast
# - Copy focus: Welcome message + collection teaser in hero, machine names only in grid
#
# Part 2 - About Us:
# - Core goal/CTA: Build brand connection and trust
# - Images to use: about-us-manifesto.png (which appears to be a text-based graphic), Melanie.webp (team member photo), and HP-Coffee machines.webp (showing the workspace/environment)
# - Layout: Since about-us-manifesto.png likely has text, I'll use it as a standalone element. Then create an asymmetrical 60/40 split with Melanie's portrait and brief text, followed by the coffee machines image as a full-width atmospheric closer
# - Color scheme: Warmer, lighter tones to contrast with the product section - beige/cream backgrounds with dark text
# - Copy focus: Ultra-brief company ethos statement</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#     &lt;/mj-attributes&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f8f6f3&quot;&gt;
#
#     &lt;!-- Hero Section with Text Overlay --&gt;
#     &lt;mj-section background-url=&quot;/uploads/DNA-Bianca.webp&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;100px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;56px&quot; font-weight=&quot;bold&quot; padding=&quot;0&quot;&gt;WELCOME HOME&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;20px&quot; padding=&quot;10px 0 30px 0&quot;&gt;Four new machines. Infinite possibilities.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#ffffff&quot; color=&quot;#2c1810&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; padding=&quot;20px&quot; inner-padding=&quot;15px 40px&quot; border-radius=&quot;0&quot;&gt;EXPLORE COLLECTION →&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Machine Grid --&gt;
#     &lt;mj-section background-color=&quot;#2c1810&quot; padding=&quot;60px 0&quot;&gt;
#       &lt;mj-column width=&quot;25%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text color=&quot;#f8f6f3&quot; align=&quot;center&quot; font-size=&quot;14px&quot; font-weight=&quot;bold&quot; padding=&quot;10px 0 0 0&quot;&gt;BIANCA&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;25%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text color=&quot;#f8f6f3&quot; align=&quot;center&quot; font-size=&quot;14px&quot; font-weight=&quot;bold&quot; padding=&quot;10px 0 0 0&quot;&gt;ELIZABETH&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;25%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESKA01+-+Kate.png&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text color=&quot;#f8f6f3&quot; align=&quot;center&quot; font-size=&quot;14px&quot; font-weight=&quot;bold&quot; padding=&quot;10px 0 0 0&quot;&gt;KATE&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;25%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text color=&quot;#f8f6f3&quot; align=&quot;center&quot; font-size=&quot;14px&quot; font-weight=&quot;bold&quot; padding=&quot;10px 0 0 0&quot;&gt;MARA X&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Divider --&gt;
#     &lt;mj-section padding=&quot;40px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-color=&quot;#2c1810&quot; border-width=&quot;1px&quot; padding=&quot;0 40px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us Title --&gt;
#     &lt;mj-section padding=&quot;0 20px 40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#2c1810&quot; font-size=&quot;42px&quot; font-weight=&quot;300&quot; font-family=&quot;Georgia, serif&quot; padding=&quot;0&quot;&gt;Our Story&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Manifesto Image --&gt;
#     &lt;mj-section padding=&quot;0 40px 40px 40px&quot;&gt;
#       &lt;annel&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Team Member Asymmetrical --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0&quot;&gt;
#       &lt;mj-column width=&quot;40%&quot; padding=&quot;0&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/Melanie.webp&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;60%&quot; vertical-align=&quot;middle&quot; padding=&quot;40px&quot;&gt;
#         &lt;mj-text color=&quot;#2c1810&quot; font-size=&quot;24px&quot; font-weight=&quot;bold&quot; padding=&quot;0 0 15px 0&quot;&gt;Crafted by obsessives.&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#2c1810&quot; font-size=&quot;16px&quot; padding=&quot;0 0 20px 0&quot;&gt;We&#x27;re engineers, baristas, and dreamers united by perfect extraction.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#2c1810&quot; color=&quot;#ffffff&quot; font-size=&quot;14px&quot; padding=&quot;0&quot; inner-padding=&quot;12px 30px&quot; border-radius=&quot;30px&quot;&gt;MEET THE TEAM&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Coffee Machines Environment --&gt;
#     &lt;mj-section padding=&quot;60px 0 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/HP-Coffee machines.webp&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer --&gt;
#     &lt;mj-section background-color=&quot;#2c1810&quot; padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#f8f6f3&quot; font-size=&quot;14px&quot;&gt;☕ Welcome to the family ☕&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#f8f6f3&quot; font-size=&quot;12px&quot; padding=&quot;20px 0 0 0&quot;&gt;© 2024 | All Rights Reserved&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Planning Stage:
#
# PART 1 - Hero/Chilean Seabass Recipe Feature:
# - Core goal/CTA: Drive clicks to the Chilean seabass recipe content
# - Images to use: o8gtNn0yeiJq.jpg (640x425) as the main hero image showing the dish
# - Layout approach: Full-bleed hero image with bold text overlay. Since this is a food image without text, I'll create a dramatic overlay with recipe name in large serif font (60px+) positioned asymmetrically over the dish. The text will be white or cream colored for contrast against what appears to be a darker food photo.
# - Color scheme: Rich, warm tones - deep ocean blues or dark grays for any background sections to evoke the sea, with cream/white text for contrast. Gold accents for premium feel befitting Chilean seabass.
# - Copy focus: Ultra-concise recipe teaser - just the dish name and one mouthwatering descriptor
#
# PART 2 - Recipe Details Section:
# - Core goal: Build desire and provide quick recipe highlights
# - Images: BL-jOWEdyIYp.jpg (640x360) to show another angle or cooking process
# - Layout: Asymmetrical 70/30 split - larger column for image, smaller for recipe quick facts in a stylized list
# - Color scheme: Continue ocean theme with lighter blue-gray background, creating depth
# - Copy: Bullet points with cook time, difficulty, and one standout ingredient
#
# PART 3 - Text Alert Signup:
# - Core goal/CTA: Drive text message opt-ins
# - Images: NoUihF8gfITs.png (640x596) if it relates to mobile/texts, or qpIEKrPysdDZ.jpg as a lifestyle image
# - Layout: Centered design with image above, signup CTA below. Use a contrasting background color block (maybe coral or warm orange) to make this section pop
# - Color scheme: Bright, attention-grabbing colors that contrast with the blues above
# - Copy: Punchy headline about exclusive recipe drops via text + simple CTA button
#
# Creative approach: I'll use a magazine-style editorial layout with the hero image bleeding to edges, dramatic typography mixing serif headers with clean sans-serif body text, and unexpected color blocking between sections to create visual rhythm.</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Arial, sans-serif&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .recipe-title {
#         text-shadow: 2px 2px 4px rgba(0,0,0,0.5);
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f4f4f4&quot;&gt;
#
#     &lt;!-- Hero Section with Text Overlay --&gt;
#     &lt;mj-section background-url=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;100px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;left&quot; color=&quot;#ffffff&quot; font-size=&quot;58px&quot; font-weight=&quot;bold&quot; font-family=&quot;Georgia, serif&quot; css-class=&quot;recipe-title&quot; padding=&quot;0&quot;&gt;
#           Chilean&lt;br/&gt;Seabass
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;left&quot; color=&quot;#f5f5dc&quot; font-size=&quot;18px&quot; font-weight=&quot;300&quot; padding=&quot;10px 0 20px 0&quot;&gt;
#           Miso-glazed perfection in 20 minutes
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;transparent&quot; color=&quot;#ffffff&quot; border=&quot;2px solid #ffffff&quot; font-size=&quot;16px&quot; font-weight=&quot;600&quot; padding=&quot;20px 0&quot; href=&quot;#&quot; inner-padding=&quot;15px 40px&quot; border-radius=&quot;0&quot;&gt;
#           GET RECIPE →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe Details Section --&gt;
#     &lt;mj-section background-color=&quot;#2c3e50&quot; padding=&quot;40px 10px&quot;&gt;
#       &lt;mj-column width=&quot;70%&quot; padding=&quot;0&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/BL-jOWEdyIYp.jpg&quot; padding=&quot;0&quot; border-radius=&quot;0 20px 20px 0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;30%&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-text color=&quot;#ffd700&quot; font-size=&quot;14px&quot; font-weight=&quot;600&quot; letter-spacing=&quot;2px&quot; padding=&quot;0 0 15px 0&quot;&gt;
#           QUICK FACTS
#         &lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#ffffff&quot; font-size=&quot;15px&quot; line-height=&quot;28px&quot; padding=&quot;0&quot;&gt;
#           ⏱ 20 mins&lt;br/&gt;
#           👤 Serves 4&lt;br/&gt;
#           ⭐ Easy&lt;br/&gt;
#           🔥 Miso glaze
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Divider --&gt;
#     &lt;mj-section padding=&quot;30px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-width=&quot;1px&quot; border-color=&quot;#e0e0e0&quot; width=&quot;50%&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Text Alert Signup Section --&gt;
#     &lt;mj-section background-color=&quot;#ff6b6b&quot; padding=&quot;50px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;42px&quot; font-weight=&quot;bold&quot; font-family=&quot;Georgia, serif&quot; padding=&quot;0 0 20px 0&quot;&gt;
#           Recipe drops. Your phone. 📱
#         &lt;/mj-text&gt;
#         &lt;mj-image src=&quot;/uploads/NoUihF8gfITs.png&quot; width=&quot;300px&quot; padding=&quot;20px 0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffe0e0&quot; font-size=&quot;18px&quot; padding=&quot;20px 0&quot;&gt;
#           Weekly exclusive recipes straight to your texts
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ffffff&quot; color=&quot;#ff6b6b&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; padding=&quot;20px 0&quot; href=&quot;#&quot; inner-padding=&quot;18px 50px&quot; border-radius=&quot;50px&quot;&gt;
#           START TEXTS
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; width=&quot;200px&quot; padding=&quot;0 0 20px 0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#888888&quot; font-size=&quot;12px&quot;&gt;
#           © 2024 All Rights Reserved
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/seafood/2025-08-26 13:17:25.453508/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">Planning Stage:
#
# Part 1 - Hero/Recipe Feature:
# - Core goal/CTA: Drive engagement with Chilean seabass recipe content, encourage cooking at home
# - Image analysis: BL-jOWEdyIYp.jpg and qpIEKrPysdDZ.jpg appear to be food/recipe related (360px height suggests content images). o8gtNn0yeiJq.jpg is larger (425px height) and could be a hero image.
# - Layout approach: I'll use o8gtNn0yeiJq.jpg as a dramatic full-bleed hero with bold text overlay. This image will anchor the recipe story.
# - Color scheme: Rich, culinary-inspired palette - deep ocean blues, warm whites, and charcoal grays to evoke both the sea and sophisticated dining
# - Creative approach: Split-screen design with the main image on one side and recipe teaser content on the other, using an asymmetrical 60/40 layout
# - Copy focus: Ultra-concise recipe hook that creates desire without over-explaining
#
# Part 2 - Recipe Details/Supporting Content:
# - Core goal: Provide recipe context and build anticipation
# - Images: Use BL-jOWEdyIYp.jpg and qpIEKrPysdDZ.jpg in a broken grid layout
# - Layout: Overlapping images with floating text blocks, creating visual interest through intentional misalignment
# - Color scheme: Continue ocean theme with seafoam green accents and sandy beige backgrounds
#
# Part 3 - Text Alert Signup:
# - Core goal/CTA: Drive text alert signups
# - Image: NoUihF8gfITs.png (596px height suggests a vertical/promotional element)
# - Layout: Centered with generous whitespace, using the image as a visual anchor
# - Color scheme: High contrast - use a deep navy background with bright white text for the CTA
# - Creative approach: Minimal design with extreme whitespace to create focus
#
# Footer:
# - Use d8FtbX8GvJh4.png (100px height suggests header/footer) and NMKa-PpjGOLD.png (62px height, likely a logo or divider)</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#2c3e50&quot; /&gt;
#       &lt;mj-button font-family=&quot;Helvetica, Arial, sans-serif&quot; font-weight=&quot;600&quot; /&gt;
#     &lt;/mj-attributes&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f8f9fa&quot;&gt;
#
#     &lt;!-- Hero Section with Split Design --&gt;
#     &lt;mj-section padding=&quot;0&quot;&gt;
#       &lt;mj-column width=&quot;60%&quot; padding=&quot;0&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; alt=&quot;Chilean Seabass&quot; padding=&quot;0&quot; border-radius=&quot;0 20px 20px 0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;40%&quot; background-color=&quot;#1a3a52&quot; padding=&quot;40px 30px&quot;&gt;
#         &lt;mj-text font-size=&quot;42px&quot; font-weight=&quot;bold&quot; color=&quot;#ffffff&quot; line-height=&quot;1.1&quot; padding-bottom=&quot;15px&quot;&gt;
#           Chilean Seabass
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;18px&quot; color=&quot;#a8c5d8&quot; font-family=&quot;Helvetica, Arial, sans-serif&quot;&gt;
#           Miso glaze. 12 minutes. Perfection.
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ff6b35&quot; color=&quot;#ffffff&quot; border-radius=&quot;30px&quot; padding-top=&quot;25px&quot; href=&quot;#&quot; font-size=&quot;16px&quot; inner-padding=&quot;15px 40px&quot;&gt;
#           GET RECIPE →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe Teaser Grid --&gt;
#     &lt;mj-section padding=&quot;60px 20px 40px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#8b9097&quot; align=&quot;center&quot; font-family=&quot;Helvetica, Arial, sans-serif&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;2px&quot;&gt;
#           🔥 Trending This Week
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;0 20px&quot;&gt;
#       &lt;mj-column width=&quot;45%&quot; padding=&quot;0&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/BL-jOWEdyIYp.jpg&quot; alt=&quot;Recipe Step&quot; border-radius=&quot;15px&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;55%&quot; padding=&quot;0 0 0 30px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; alt=&quot;Final Dish&quot; border-radius=&quot;15px&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text background-color=&quot;#e8f4f8&quot; padding=&quot;20px&quot; border-radius=&quot;10px&quot; margin-top=&quot;-40px&quot; font-family=&quot;Helvetica, Arial, sans-serif&quot; font-size=&quot;15px&quot;&gt;
#           Sake-miso marinade transforms buttery fish into restaurant magic.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Text Alert Section --&gt;
#     &lt;mj-section background-color=&quot;#0f2940&quot; padding=&quot;80px 20px&quot; margin-top=&quot;60px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NoUihF8gfITs.png&quot; alt=&quot;Text Alerts&quot; width=&quot;300px&quot; padding-bottom=&quot;30px&quot; /&gt;
#         &lt;mj-text font-size=&quot;28px&quot; color=&quot;#ffffff&quot; align=&quot;center&quot; font-weight=&quot;bold&quot; padding-bottom=&quot;10px&quot;&gt;
#           Recipe drops. Your phone.
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;16px&quot; color=&quot;#7fa8c7&quot; align=&quot;center&quot; font-family=&quot;Helvetica, Arial, sans-serif&quot;&gt;
#           Weekly exclusive recipes via text 📱
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ffffff&quot; color=&quot;#0f2940&quot; border-radius=&quot;50px&quot; padding-top=&quot;30px&quot; font-size=&quot;18px&quot; inner-padding=&quot;18px 50px&quot; href=&quot;#&quot;&gt;
#           START TEXTS
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer --&gt;
#     &lt;mj-section padding=&quot;40px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; alt=&quot;Logo&quot; width=&quot;200px&quot; padding-bottom=&quot;20px&quot; /&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; alt=&quot;Divider&quot; width=&quot;100px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/seafood/2025-08-26 13:18:24.843729/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">This email will promote an annual quilting event in Portsmouth, NH that brings together quilters of all skill levels.
#
# Part 1 - Hero Section:
# - Core goal: Generate excitement and establish the event as a must-attend gathering
# - Images: q1rNLeA5MGW4.png (1280x730) would work well as a hero banner - it's landscape format and could showcase quilting imagery
# - Layout: Full-width hero with text overlay. Since this is a wide image, I'll use it as a background with bold white text overlaid for the event name and date
# - Color scheme: Warm, crafty colors - using coral, cream, and navy to evoke both tradition and creativity
# - Copy focus: Event name, date, and the inclusive community aspect
#
# Part 2 - Event Details Grid:
# - Core goal: Showcase what makes this event special for both beginners and experts
# - Images: I'll use the square format images (IE9az4JoTkMu.png, KcswBqLO-Ff_.png, N4807TOO3CUx.png) in a 3-column grid to show different aspects of quilting
# - Layout: Three equal columns with rounded images, each highlighting a different aspect (community, learning, creating)
# - Color scheme: Alternating background colors in soft pastels to create a patchwork effect
# - Copy focus: Brief descriptors of what attendees can expect
#
# Part 3 - Featured Highlight:
# - Core goal: Drive registration with special workshop or instructor spotlight
# - Images: 7oP1eqIoGS-J.png (935x568) for a featured section
# - Layout: Asymmetrical 60/40 split with image on left, text on right
# - Color scheme: Deep indigo background with cream text for contrast
# - Copy focus: One compelling reason to register now
#
# Part 4 - Call to Action:
# - Core goal: Get immediate registrations
# - Images: bHyb-RbQe-aY.jpg (1013x283) as a footer banner or EZItMmj9aQSE.png for a smaller accent
# - Layout: Centered CTA with decorative element
# - Color scheme: Bold coral button on cream background
# - Copy focus: Urgency and community</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#2c3e50&quot; /&gt;
#       &lt;mj-button font-family=&quot;Arial, sans-serif&quot; font-weight=&quot;bold&quot; /&gt;
#     &lt;/mj-attributes&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#faf8f5&quot;&gt;
#
#     &lt;!-- Hero Section with Overlay --&gt;
#     &lt;mj-section background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;100px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;56px&quot; font-weight=&quot;bold&quot; color=&quot;#ffffff&quot; padding=&quot;0&quot;&gt;
#           PORTSMOUTH QUILTS &#x27;24
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;22px&quot; color=&quot;#ffffff&quot; padding-top=&quot;10px&quot;&gt;
#           March 15-17 • Where threads unite
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Patchwork Grid Section --&gt;
#     &lt;mj-section padding=&quot;60px 20px 30px 20px&quot;&gt;
#       &lt;mj-column width=&quot;33.33%&quot; background-color=&quot;#ffd6cc&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; border-radius=&quot;20px&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; color=&quot;#d84315&quot; padding-top=&quot;15px&quot;&gt;
#           LEARN 🪡
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#2c3e50&quot;&gt;
#           Master techniques from binding to appliqué
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33.33%&quot; background-color=&quot;#e8f5e9&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; border-radius=&quot;20px&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; color=&quot;#2e7d32&quot; padding-top=&quot;15px&quot;&gt;
#           CREATE ✂️
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#2c3e50&quot;&gt;
#           Design your own modern heirloom
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33.33%&quot; background-color=&quot;#fff3e0&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; border-radius=&quot;20px&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; color=&quot;#e65100&quot; padding-top=&quot;15px&quot;&gt;
#           CONNECT 🤝
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#2c3e50&quot;&gt;
#           Join 200+ makers sharing stories
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Featured Workshop Section --&gt;
#     &lt;mj-section background-color=&quot;#1a237e&quot; padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column width=&quot;60%&quot; padding=&quot;0&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/7oP1eqIoGS-J.png&quot; border-radius=&quot;0 30px 30px 0&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;40%&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-text font-size=&quot;24px&quot; font-weight=&quot;bold&quot; color=&quot;#ffd54f&quot; padding=&quot;0&quot;&gt;
#           Featured: Japanese Sashiko
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;16px&quot; color=&quot;#ffffff&quot; padding-top=&quot;15px&quot;&gt;
#           Award-winning artist Yuki Tanaka leads an exclusive workshop.
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#b39ddb&quot; padding-top=&quot;10px&quot; font-style=&quot;italic&quot;&gt;
#           Limited to 15 quilters
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- CTA Section with Coupon Style --&gt;
#     &lt;mj-section padding=&quot;50px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;20px&quot; color=&quot;#d84315&quot; padding-bottom=&quot;20px&quot;&gt;
#           Early bird pricing ends February 1st
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ff5722&quot; color=&quot;#ffffff&quot; font-size=&quot;18px&quot; padding=&quot;15px 40px&quot; border-radius=&quot;50px&quot; href=&quot;#&quot;&gt;
#           CLAIM YOUR SPOT →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer Banner --&gt;
#     &lt;mj-section padding=&quot;0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/bHyb-RbQe-aY.jpg&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/craft store/2025-08-26 13:19:22.707102/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; gap:20px; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
# <div style="font-size:16pt; font-weight:bold; margin-top:0; padding-top:0;">PLANNING STEP</div>
# <div style="white-space: pre-wrap;">This email needs to celebrate the annual quilting event in Portsmouth NH, appealing to both novice and advanced quilters. I'll create 3 main sections:
#
# Section 1 - Hero/Event Announcement:
# - Goal/CTA: Build excitement and drive event registration
# - Image: q1rNLeA5MGW4.png (1280x730) - This wider aspect ratio works perfectly as a hero banner. I'll use it as a background with bold text overlay announcing the event
# - Layout: Full-width background image with centered text overlay. The text needs to be large (60px+), bold, and white or very light to contrast against potential darker areas
# - Color scheme: I'll use warm, crafty colors - perhaps a cream/beige background with navy text for other sections to evoke traditional quilting aesthetics
#
# Section 2 - Community Showcase:
# - Goal/CTA: Show the inclusive nature of the event (novice to advanced)
# - Images: I'll use a 3-column layout with N4807TOO3CUx.png, IE9az4JoTkMu.png, and hA2OiBty-zz0.png to showcase variety
# - Layout: Three equal columns showing different quilting styles/levels. Each image gets rounded corners for a softer, crafted feel
# - Color scheme: Soft background (light gray or cream) to let the colorful quilt images pop
#
# Section 3 - Registration/Details:
# - Goal/CTA: Drive registrations with event details
# - Images: ZWonHtct7o2E.png (404x511) and EZItMmj9aQSE.png (507x514) in an asymmetrical 40/60 split
# - Layout: Two-column asymmetrical layout with event details on the larger side and a decorative image on the smaller side
# - Color scheme: Navy background with white text for high contrast, creating a 'evening gathering' feel
#
# Copy strategy: Keep it minimal - let the community aspect shine through. Focus on 'annual tradition', 'all skill levels welcome', and clear event details.</div>
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .coupon-box {
#         border: 2px dashed #2C3E50;
#         background-color: #FFF8DC;
#         padding: 15px;
#         border-radius: 8px;
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FAFAFA&quot;&gt;
#
#     &lt;!-- Hero Section with Image Background --&gt;
#     &lt;mj-section background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;56px&quot; font-weight=&quot;bold&quot; font-family=&quot;Helvetica, sans-serif&quot; line-height=&quot;1.1&quot;&gt;
#           PORTSMOUTH QUILTS 2024
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;22px&quot; font-family=&quot;Helvetica, sans-serif&quot; padding-top=&quot;10px&quot;&gt;
#           Annual gathering • All skill levels
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#E74C3C&quot; color=&quot;#FFFFFF&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; border-radius=&quot;30px&quot; padding=&quot;20px 0&quot; href=&quot;#&quot; font-family=&quot;Helvetica, sans-serif&quot;&gt;
#           Reserve Your Spot →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Community Showcase --&gt;
#     &lt;mj-section background-color=&quot;#F5F5DC&quot; padding=&quot;60px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#2C3E50&quot; font-size=&quot;32px&quot; font-weight=&quot;300&quot; padding-bottom=&quot;30px&quot;&gt;
#           Novice to Master. Everyone Creates.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#F5F5DC&quot; padding=&quot;0 20px 60px&quot;&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; border-radius=&quot;15px&quot; padding=&quot;10px&quot; alt=&quot;Quilting pattern example&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; border-radius=&quot;15px&quot; padding=&quot;10px&quot; alt=&quot;Community quilting&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/hA2OiBty-zz0.png&quot; border-radius=&quot;15px&quot; padding=&quot;10px&quot; alt=&quot;Quilt design showcase&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Event Details Section --&gt;
#     &lt;mj-section background-color=&quot;#2C3E50&quot; padding=&quot;50px 20px&quot;&gt;
#       &lt;mj-column width=&quot;40%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/ZWonHtct7o2E.png&quot; border-radius=&quot;10px&quot; alt=&quot;Featured quilt design&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;60%&quot; padding-left=&quot;30px&quot;&gt;
#         &lt;mj-text color=&quot;#FFFFFF&quot; font-size=&quot;28px&quot; font-weight=&quot;bold&quot; font-family=&quot;Helvetica, sans-serif&quot;&gt;
#           March 15-17 🪡
#         &lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#FFFFFF&quot; font-size=&quot;18px&quot; padding-top=&quot;15px&quot; font-family=&quot;Helvetica, sans-serif&quot;&gt;
#           Three days. Unlimited inspiration.
#         &lt;/mj-text&gt;
#         &lt;mj-divider border-color=&quot;#E74C3C&quot; border-width=&quot;3px&quot; width=&quot;50px&quot; padding=&quot;20px 0&quot; align=&quot;left&quot; /&gt;
#         &lt;mj-text color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; font-family=&quot;Helvetica, sans-serif&quot;&gt;
#           📍 Portsmouth Convention Center&lt;br/&gt;
#           💵 $85 early bird (save $20)&lt;br/&gt;
#           ✂️ Materials included
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#FFFFFF&quot; color=&quot;#2C3E50&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; border-radius=&quot;25px&quot; padding=&quot;30px 0&quot; href=&quot;#&quot; font-family=&quot;Helvetica, sans-serif&quot;&gt;
#           Register Now
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Special Offer --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column width=&quot;70%&quot;&gt;
#         &lt;mj-wrapper css-class=&quot;coupon-box&quot;&gt;
#           &lt;mj-text align=&quot;center&quot; color=&quot;#2C3E50&quot; font-size=&quot;24px&quot; font-weight=&quot;bold&quot;&gt;
#             QUILT2024
#           &lt;/mj-text&gt;
#           &lt;mj-text align=&quot;center&quot; color=&quot;#666&quot; font-size=&quot;14px&quot;&gt;
#             Group discount: 15% off for 3+ registrations
#           &lt;/mj-text&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer --&gt;
#     &lt;mj-section padding=&quot;30px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#999&quot; font-size=&quot;14px&quot;&gt;
#           Questions? Reply to this email or call (603) 555-0123
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align
