# %% [markdown]
# ## Purpose
# - Test simpler prompt for generating emails.
#
# ## Conclusion
# - this prompt + Claude Opus was the strongest overall combination, although this prompt + GPT-5 was worse than the "complex" prompt.
#
#
# ## Results
# - Overall, Claude does the best, with fewer clear errors and interesting, unexpected designs. GPT-5 also has strong designs, but far more mistakes and strange layout choices.
# - Claude Opus 4.1
#     - Creative, unexpected, aesthetic designs
#     - Text overlays are better, but still sometimes struggle a bit with contrast
#     - Does a good job wit images that  have text overlays (although still makes some mistakes here, such as adding a redundant CTA button after an image that already has one)
# - GPT-5
#   - low reasoning effort:
#     - emails have good general design and colors
#     - but often have strange issues (text overlays too small, large amounts of whitespace, text box or button width is far too thin)
#     - model often thrown off by images that are multi-part or have text overlays (places them in areas that are too small, has unneeded extra text)
#   - medium / high reasoning effort:
#     - Better designs than low reasoning effort, with more interesting/unexpected design ideas.
#     - Makes similar layout mistakes - often more severe than the low reasoning effort versions.

# %%
import importlib as imp  
import test_prompts
imp.reload(test_prompts)
# Out:
# <module 'test_prompts' from '/Users/charlienatoli/coding_projects/email-designer/notebooks/test_prompts.py'>

# %%
EMAIL_SYSTEM_PROMPT_BASIC =  """You are a creative email design bot. Your job is to draft marketing emails that will be reviewed by a human marketing designer. 
These emails should fit well into the company's brand style, but also be unique and interesting. The goal is to give new ideas to the marketing team that they can take inspiration from. 
 
<images-available>
You can use any of the uploaded images listed below in the email you design.
{imageContext}

Rules for using images:
- For images, reference the uploaded files by filename from the catalog above.
- Set the image src to /uploads/<image-filename> where <image-filename> includes the extension, e.g. /uploads/abc123.jpg.
- To use an image as a background, set the image src to /uploads/<image-filename> and use the background-url attribute in mj-section. You can then place text or other content over the image by placing those elements inside the mj-section.
</images-available>

<design-guidelines>
General guidelines:
- Be creative and bold with layouts, visuals, and typography while staying on-brand.
- Include clear, actionable CTAs using compelling text.
- Make the primary CTA prominent and near the top; add secondary CTAs if there are multiple actions the reader can take. 
</design-guidelines>

<final-output-format>
- Return only the MJML must start with <mjml> and include <mj-body> wrapping the entire email content. Return ONLY the MJML, no other text.
</final-output-format>
"""

# %%
## Testing Claude
for test_case, prompt in [
    ['coffee', 'customer welcome email. start with introducing our new collection of espresso machines. Then add more about us below that.'], 
    ['seafood', 'focus of the email should be the chilean seabass recipe section. Come up with an interesting way to show this. Then include a note to sign up for text alerts below that'],
    ['craft store','annual create a quilt event. Bringing together novice and advanced quilters from around Portsmouth NH to create beautiful new designs.']
]:
    for _ in range(2): 
        output_text = test_prompts.generate_emails_from_prompt(
            system_prompt=EMAIL_SYSTEM_PROMPT_BASIC, 
            test_case=test_case,
            creative_brief=prompt,
            has_plan_step_in_output=False,
            provider="anthropic"
        )
# Out:
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-font name=&quot;Montserrat&quot; href=&quot;https://fonts.googleapis.com/css2?family=Montserrat:wght@400;600;700&amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Montserrat, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#333333&quot; /&gt;
#       &lt;mj-button background-color=&quot;#D4521C&quot; color=&quot;#ffffff&quot; font-weight=&quot;600&quot; font-size=&quot;16px&quot; border-radius=&quot;30px&quot; padding=&quot;15px 40px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f8f6f4&quot;&gt;
#
#     &lt;!-- Hero Section --&gt;
#     &lt;mj-section padding=&quot;0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;42px&quot; font-weight=&quot;700&quot; color=&quot;#1a1a1a&quot; padding=&quot;40px 20px 10px&quot;&gt;
#           Welcome to Excellence
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#666666&quot; padding=&quot;0 40px 30px&quot;&gt;
#           Your journey to extraordinary coffee begins here
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- New Collection Introduction --&gt;
#     &lt;lj-section background-color=&quot;#ffffff&quot; padding=&quot;0&quot; border-radius=&quot;8px 8px 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;32px&quot; font-weight=&quot;600&quot; color=&quot;#D4521C&quot; padding=&quot;50px 20px 20px&quot;&gt;
#           Introducing Our Artisan Collection
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;17px&quot; padding=&quot;0 40px 40px&quot; color=&quot;#555555&quot;&gt;
#           Four masterpieces of Italian engineering, each crafted to transform your coffee ritual into an art form.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Machine Grid --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; font-size=&quot;20px&quot; padding=&quot;15px 0 5px&quot; color=&quot;#1a1a1a&quot;&gt;
#           Bianca
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 10px 20px&quot;&gt;
#           Dual boiler perfection for the true connoisseur
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; font-size=&quot;20px&quot; padding=&quot;15px 0 5px&quot; color=&quot;#1a1a1a&quot;&gt;
#           MaraX
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 10px 20px&quot;&gt;
#           Heat exchange innovation meets elegant design
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px 40px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; font-size=&quot;20px&quot; padding=&quot;15px 0 5px&quot; color=&quot;#1a1a1a&quot;&gt;
#           Elizabeth
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 10px 20px&quot;&gt;
#           Smart features for consistent excellence
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESKA01+-+Kate.png&quot; alt=&quot;Kate Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; font-size=&quot;20px&quot; padding=&quot;15px 0 5px&quot; color=&quot;#1a1a1a&quot;&gt;
#           Kate
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 10px 20px&quot;&gt;
#           Compact powerhouse for modern kitchens
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- CTA Section --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px 50px&quot; border-radius=&quot;0 0 8px 8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-button href=&quot;#&quot; padding=&quot;0&quot;&gt;
#           Explore the Collection
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us Section --&gt;
#     &lt;mj-section padding=&quot;40px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;28px&quot; font-weight=&quot;600&quot; color=&quot;#1a1a1a&quot;&gt;
#           More Than Machines
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(26, 26, 26, 0.85)&quot; border-radius=&quot;8px&quot; padding=&quot;40px 30px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;20px&quot; font-weight=&quot;600&quot; padding=&quot;0 0 20px&quot;&gt;
#           Our Story
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#f0f0f0&quot; font-size=&quot;15px&quot; line-height=&quot;1.8&quot;&gt;
#           For over two decades, we&#x27;ve been obsessed with one thing: helping you create the perfect cup. From our Italian workshops to your kitchen counter, every machine carries our commitment to precision, durability, and the pure joy of exceptional espresso.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Manifesto --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; alt=&quot;Our Manifesto&quot; width=&quot;400px&quot; padding=&quot;20px 0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;15px&quot; color=&quot;#666666&quot; padding=&quot;20px 30px&quot;&gt;
#           We believe great coffee is a ritual worth perfecting. It&#x27;s about slowing down, paying attention, and crafting something beautiful—one shot at a time.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Secondary CTA --&gt;
#     &lt;mj-section padding=&quot;20px 20px 60px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;600&quot; color=&quot;#1a1a1a&quot; padding=&quot;0 0 25px&quot;&gt;
#           Ready to elevate your coffee experience?
#         &lt;/mj-text&gt;
#         &lt;mj-but
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#333333&quot; /&gt;
#       &lt;mj-button background-color=&quot;#000000&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; border-radius=&quot;0px&quot; padding=&quot;15px 30px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .hero-title {
#         font-size: 48px !important;
#         line-height: 1.2 !important;
#         font-weight: 300 !important;
#         letter-spacing: -1px !important;
#       }
#       .subtitle {
#         font-size: 20px !important;
#         font-weight: 300 !important;
#         color: #666666 !important;
#       }
#       .section-title {
#         font-size: 32px !important;
#         font-weight: 300 !important;
#         letter-spacing: -0.5px !important;
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#ffffff&quot;&gt;
#
#     &lt;!-- Welcome Hero --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot; background-color=&quot;#f8f8f8&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;hero-title&quot; color=&quot;#000000&quot; padding=&quot;0 0 20px 0&quot;&gt;
#           Welcome to Excellence
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;subtitle&quot; padding=&quot;0 0 30px 0&quot;&gt;
#           Your journey to the perfect espresso begins here
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- New Collection Introduction --&gt;
#     &lt;mj-section padding=&quot;60px 20px 40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;section-title&quot; color=&quot;#000000&quot; padding=&quot;0 0 30px 0&quot;&gt;
#           Introducing Our New Collection
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 0 40px 0&quot; color=&quot;#666666&quot;&gt;
#           Four exceptional machines, each crafted with Italian precision and designed to transform your coffee ritual into an art form.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Machine Grid --&gt;
#     &lt;mj-section padding=&quot;0 20px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESKA01+-+Kate.png&quot; alt=&quot;Kate Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;600&quot; padding=&quot;15px 0 5px 0&quot;&gt;KATE&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 0 20px 0&quot;&gt;Compact Perfection&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;600&quot; padding=&quot;15px 0 5px 0&quot;&gt;ELIZABETH&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 0 20px 0&quot;&gt;Dual Boiler Excellence&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;0 20px 40px 20px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;600&quot; padding=&quot;15px 0 5px 0&quot;&gt;MARA X&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 0 20px 0&quot;&gt;Smart Temperature Control&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;10px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca Espresso Machine&quot; padding=&quot;0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;600&quot; padding=&quot;15px 0 5px 0&quot;&gt;BIANCA&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;0 0 20px 0&quot;&gt;Professional Home Barista&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- CTA Section --&gt;
#     &lt;මj-section padding=&quot;20px 20px 60px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot;&gt;
#           EXPLORE THE COLLECTION
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us Section with Background --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(255,255,255,0.95)&quot; padding=&quot;40px 30px&quot; border-radius=&quot;0px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;section-title&quot; color=&quot;#000000&quot; padding=&quot;0 0 25px 0&quot;&gt;
#           Our Story
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 0 25px 0&quot;&gt;
#           Born from a passion for coffee and Italian craftsmanship, we believe that making espresso at home should be an experience worth savoring. Every machine we create is designed to bring the café experience into your kitchen.
#         &lt;/mj-text&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; alt=&quot;Our Manifesto&quot; width=&quot;300px&quot; padding=&quot;20px 0&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot; padding=&quot;20px 0 0 0&quot;&gt;
#           We don&#x27;t just make machines. We craft moments. We engineer rituals. We perfect mornings.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Values Section --&gt;
#     &lt;mj-section padding=&quot;60px 20px&quot; background-color=&quot;#f8f8f8&quot;&gt;
#       &lt;mj-column width=&quot;33.33%&quot; padding=&quot;0 10px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; padding=&quot;0 0 10px 0&quot;&gt;🇮🇹&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; padding=&quot;0 0 10px 0&quot;&gt;Italian Heritage&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;Designed and manufactured in Italy since 1986&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33.33%&quot; padding=&quot;0 10px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; padding=&quot;0 0 10px 0&quot;&gt;⚙️&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;600&quot; padding=&quot;0 0 10px 0&quot;&gt;Precision Engineering&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;Every component carefully crafted for consistency&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-co
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#2c3e50&quot; /&gt;
#       &lt;mj-button background-color=&quot;#e74c3c&quot; border-radius=&quot;30px&quot; font-size=&quot;16px&quot; padding=&quot;15px 30px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .recipe-title {
#         font-size: 42px !important;
#         font-weight: 300 !important;
#         letter-spacing: -1px !important;
#         color: #1a1a1a !important;
#       }
#       .ingredient-tag {
#         background: #f8f4e6;
#         padding: 8px 16px;
#         border-radius: 20px;
#         display: inline-block;
#         margin: 4px;
#         font-size: 14px;
#         color: #5a5a5a;
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#ffffff&quot;&gt;
#
#     &lt;mj-section padding=&quot;20px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; width=&quot;300px&quot; alt=&quot;Logo&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-url=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(255,255,255,0.95)&quot; border-radius=&quot;10px&quot; padding=&quot;40px 30px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#e74c3c&quot; font-weight=&quot;600&quot; letter-spacing=&quot;2px&quot;&gt;TONIGHT&#x27;S MASTERPIECE&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;recipe-title&quot; padding=&quot;10px 0 20px 0&quot;&gt;Pan-Seared Chilean Sea Bass&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#666&quot; font-style=&quot;italic&quot; padding-bottom=&quot;30px&quot;&gt;Buttery, flaky perfection in just 20 minutes&lt;/mj-text&gt;
#
#         &lt;mj-divider border-color=&quot;#e0e0e0&quot; border-width=&quot;1px&quot; padding=&quot;20px 0&quot; /&gt;
#
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;12px&quot; color=&quot;#999&quot; letter-spacing=&quot;1px&quot; padding-bottom=&quot;15px&quot;&gt;KEY INGREDIENTS&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot;&gt;
#           &lt;span class=&quot;ingredient-tag&quot;&gt;Chilean Sea Bass&lt;/span&gt;
#           &lt;span class=&quot;ingredient-tag&quot;&gt;Lemon Butter&lt;/span&gt;
#           &lt;span class=&quot;ingredient-tag&quot;&gt;Fresh Thyme&lt;/span&gt;
#           &lt;span class=&quot;ingredient-tag&quot;&gt;White Wine&lt;/span&gt;
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;24px&quot; align=&quot;center&quot; color=&quot;#1a1a1a&quot; padding-bottom=&quot;20px&quot;&gt;The Secret? It&#x27;s All in the Sear.&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 40px&quot;&gt;
#           Get that restaurant-quality golden crust at home. Our foolproof technique ensures your sea bass comes out perfectly every time – crispy outside, tender and flaky inside.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot; padding=&quot;30px 0&quot;&gt;
#           Get the Full Recipe
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#f8f4e6&quot; padding=&quot;40px 20px&quot; border-radius=&quot;10px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NoUihF8gfITs.png&quot; width=&quot;80px&quot; alt=&quot;Phone icon&quot; padding-bottom=&quot;20px&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;20px&quot; color=&quot;#1a1a1a&quot; font-weight=&quot;600&quot; padding-bottom=&quot;15px&quot;&gt;
#           Never Miss a Recipe Drop
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 30px 25px 30px&quot;&gt;
#           Get exclusive recipes and cooking tips sent straight to your phone. Text alerts mean you&#x27;ll be the first to know about our latest culinary creations.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#2c3e50&quot; align=&quot;center&quot;&gt;
#           Sign Up for Text Alerts
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;40px 20px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; width=&quot;400px&quot; alt=&quot;Footer decoration&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/seafood/2025-08-26 14:52:27.573127/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#2c3e50&quot; /&gt;
#       &lt;mj-button background-color=&quot;#e74c3c&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; border-radius=&quot;4px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .recipe-title {
#         font-size: 42px !important;
#         line-height: 1.2 !important;
#         letter-spacing: -1px !important;
#       }
#       .ingredient-box {
#         background: #fef5e7;
#         border-left: 4px solid #e74c3c;
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f8f9fa&quot;&gt;
#
#     &lt;!-- Logo Header --&gt;
#     &lt;mj-section padding=&quot;20px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; width=&quot;320px&quot; alt=&quot;Logo&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Hero Image with Overlay Text --&gt;
#     &lt;mj-section background-url=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(255,255,255,0.92)&quot; padding=&quot;30px&quot; border-radius=&quot;8px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#e74c3c&quot; font-weight=&quot;bold&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;2px&quot;&gt;
#           Tonight&#x27;s Dinner
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;recipe-title&quot; color=&quot;#2c3e50&quot; font-weight=&quot;bold&quot; padding=&quot;10px 0&quot;&gt;
#           Pan-Seared Chilean Seabass
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#7f8c8d&quot; font-style=&quot;italic&quot;&gt;
#           Buttery, flaky perfection in just 20 minutes
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe Content Split Layout --&gt;
#     &lt;mj-section padding=&quot;40px 20px 20px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding-right=&quot;15px&quot;&gt;
#         &lt;mj-text font-size=&quot;22px&quot; font-weight=&quot;bold&quot; color=&quot;#e74c3c&quot; padding-bottom=&quot;15px&quot;&gt;
#           What You&#x27;ll Need:
#         &lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;ingredient-box&quot; padding=&quot;20px&quot; line-height=&quot;2&quot;&gt;
#           • 4 Chilean seabass fillets (6 oz each)&lt;br/&gt;
#           • 3 tbsp unsalted butter&lt;capturing br/&gt;
#           • 2 cloves garlic, minced&lt;br/&gt;
#           • Fresh thyme sprigs&lt;br/&gt;
#           • 1 lemon, sliced&lt;br/&gt;
#           • Sea salt &amp; black pepper&lt;br/&gt;
#           • 2 tbsp olive oil
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#
#       &lt;mj-column width=&quot;50%&quot; padding-left=&quot;15px&quot;&gt;
#         &lt;mj-text font-size=&quot;22px&quot; font-weight=&quot;bold&quot; color=&quot;#e74c3c&quot; padding-bottom=&quot;15px&quot;&gt;
#           The Magic Method:
#         &lt;/mj-text&gt;
#         &lt;mj-text line-height=&quot;1.8&quot;&gt;
#           &lt;strong&gt;1.&lt;/strong&gt; Pat fish dry, season generously&lt;br/&gt;
#           &lt;strong&gt;2.&lt;/strong&gt; Heat oil in cast iron until shimmering&lt;br/&gt;
#           &lt;strong&gt;3.&lt;/strong&gt; Sear 4 minutes, flip once golden&lt;br/&gt;
#           &lt;strong&gt;4.&lt;/strong&gt; Add butter, garlic &amp; thyme&lt;br/&gt;
#           &lt;strong&gt;5.&lt;/strong&gt; Baste for 3 minutes&lt;br/&gt;
#           &lt;strong&gt;6.&lt;/strong&gt; Rest 2 minutes, squeeze lemon
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Chef&#x27;s Secret Tip --&gt;
#     &lt;mj-section padding=&quot;20px&quot;&gt;
#       &lt;mj-column background-color=&quot;#2c3e50&quot; border-radius=&quot;8px&quot; padding=&quot;30px&quot;&gt;
#         &lt;mj-text color=&quot;#ffffff&quot; font-size=&quot;18px&quot; font-weight=&quot;bold&quot; padding-bottom=&quot;10px&quot;&gt;
#           🔥 Chef&#x27;s Secret:
#         &lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#ecf0f1&quot; font-size=&quot;16px&quot;&gt;
#           The key to restaurant-quality seabass? Room temperature fish + scorching hot pan + no touching for the first 4 minutes. Trust the process.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- CTA Button --&gt;
#     &lt;mj-section padding=&quot;30px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-button href=&quot;#&quot; padding=&quot;20px 0&quot; font-size=&quot;18px&quot; inner-padding=&quot;15px 40px&quot;&gt;
#           Get Full Recipe + Wine Pairing →
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Divider --&gt;
#     &lt;mj-section padding=&quot;0 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-color=&quot;#e0e0e0&quot; border-width=&quot;1px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Text Alerts Section --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot; background-color=&quot;#fef5e7&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NoUihF8gfITs.png&quot; width=&quot;80px&quot; alt=&quot;Phone icon&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; font-weight=&quot;bold&quot; color=&quot;#2c3e50&quot; padding=&quot;20px 0 10px&quot;&gt;
#           Never Miss a Recipe Drop
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;16px&quot; color=&quot;#7f8c8d&quot; padding=&quot;0 40px 20px&quot;&gt;
#           Get instant text alerts when we release new recipes, flash sales on premium ingredients, and exclusive chef tips. Join 50,000+ home cooks.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#2c3e50&quot; font-size=&quot;16px&quot; inner-padding=&quot;12px 30px&quot;&gt;
#           Sign Up for Text Alerts
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;13px&quot; color=&quot;#95a5a6&quot; padding-top=&quot;10px&quot;&gt;
#           Text COOK to 12345 | 2-3 texts/week | Msg &amp; data rates may apply
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer --&gt;
#     &lt;mj-section padding=&quot;30px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#95a5a6&quot;&gt;
#           © 2024 Your Kitchen Co. | &lt;a href=&quot;#&quot; style=&quot;color:#e74c3c;&quot;&gt;Unsubscribe&lt;/a&gt; | &lt;a href=&quot;#&quot; style=&quot;color:#e74c3c;&quot;&gt;View in Browser&lt;/a&gt;
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/seafood/2025-08-26 14:53:54.139271/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#2c3e50&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .headline { font-family: &#x27;Trebuchet MS&#x27;, sans-serif !important; }
#       .script-text { font-family: &#x27;Brush Script MT&#x27;, cursive !important; font-style: italic; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#faf8f5&quot;&gt;
#
#     &lt;!-- Hero Section with Background --&gt;
#     &lt;mj-section background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-position=&quot;center&quot; padding=&quot;80px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;48px&quot; color=&quot;#ffffff&quot; font-weight=&quot;bold&quot; css-class=&quot;headline&quot; padding-bottom=&quot;20px&quot;&gt;
#           Threads That Bind Us
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; color=&quot;#ffffff&quot; css-class=&quot;script-text&quot;&gt;
#           Annual Portsmouth Quilt Gathering 2024
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Intro Section --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;40px 25px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;20px&quot; color=&quot;#8b4513&quot; align=&quot;center&quot; padding-bottom=&quot;20px&quot;&gt;
#           Where Stories Are Stitched &amp; Friendships Are Sewn
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot;&gt;
#           Join us for Portsmouth&#x27;s most anticipated quilting event of the year. Whether you&#x27;re threading your first needle or have decades of quilting wisdom to share, this gathering celebrates every stitch of your journey.
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#d2691e&quot; color=&quot;#ffffff&quot; font-size=&quot;18px&quot; padding=&quot;30px 0&quot; href=&quot;#&quot;&gt;
#           Reserve Your Spot Today
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Two Column Feature --&gt;
#     &lt;mj-section background-color=&quot;#f5e6d3&quot; padding=&quot;40px 15px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; alt=&quot;Quilting patterns&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; vertical-align=&quot;middle&quot;&gt;
#         &lt;mj-text font-size=&quot;22px&quot; color=&quot;#8b4513&quot; font-weight=&quot;bold&quot; padding-bottom=&quot;15px&quot;&gt;
#           What Awaits You
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           • Hands-on workshops for all skill levels&lt;br/&gt;
#           • Pattern swap &amp; vintage fabric market&lt;br/&gt;
#           • Guest artist demonstrations&lt;brussele/&gt;
#           • Community quilt project reveal&lt;br/&gt;
#           • Tea time with fellow quilters
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Gallery Section --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;40px 10px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;28px&quot; color=&quot;#2c3e50&quot; padding-bottom=&quot;25px&quot; css-class=&quot;headline&quot;&gt;
#           Last Year&#x27;s Masterpieces
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 10px 40px&quot;&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; alt=&quot;Quilt design 1&quot; padding=&quot;5px&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/hA2OiBty-zz0.png&quot; alt=&quot;Quilt design 2&quot; padding=&quot;5px&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; alt=&quot;Quilt design 3&quot; padding=&quot;5px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Event Details --&gt;
#     &lt;mj-section background-color=&quot;#8b4513&quot; padding=&quot;50px 25px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;32px&quot; color=&quot;#ffffff&quot; font-weight=&quot;bold&quot; padding-bottom=&quot;25px&quot;&gt;
#           Mark Your Calendar
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;18px&quot;&gt;
#           &lt;strong&gt;Saturday, April 27th&lt;/strong&gt;&lt;br/&gt;
#           9:00 AM - 5:00 PM&lt;br/&gt;
#           Portsmouth Harbor Events Center&lt;br/&gt;
#           100 Market Street, Portsmouth NH
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffd700&quot; font-size=&quot;20px&quot; padding-top=&quot;20px&quot;&gt;
#           Early Bird Special: $45 (Regular $65)
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ffffff&quot; color=&quot;#8b4513&quot; font-size=&quot;18px&quot; padding=&quot;30px 0&quot; href=&quot;#&quot;&gt;
#           Secure Your Space Now
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Testimonial --&gt;
#     &lt;mj-section background-color=&quot;#f5e6d3&quot; padding=&quot;40px 25px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-style=&quot;italic&quot; color=&quot;#2c3e50&quot; padding=&quot;0 30px&quot;&gt;
#           &quot;I came as a beginner, nervous about my skills. I left with new friends, incredible techniques, and the confidence to tackle my dream quilt. This event is pure magic!&quot;
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#8b4513&quot; padding-top=&quot;15px&quot;&gt;
#           — Sarah M., 2023 Attendee
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Footer CTA --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;40px 25px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; color=&quot;#2c3e50&quot; padding-bottom=&quot;20px&quot;&gt;
#           Limited to 150 Quilters
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding-bottom=&quot;25px&quot;&gt;
#           Don&#x27;t miss your chance to be part of Portsmouth&#x27;s most inspiring day of creativity and connection.
#         &lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#d2691e&quot; color=&quot;#ffffff&quot; font-size=&quot;20px&quot; font-weight=&quot;bold&quot; padding=&quot;0 0 30px&quot; href=&quot;#&quot;&gt;
#           Join the 2024 Quilt Gathering
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#666666&quot;&gt;
#           Questions? Reply to this email or call (603) 555-QUILT
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Georgia, serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#4a4a4a&quot; /&gt;
#       &lt;mj-button background-color=&quot;#d35400&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; font-weight=&quot;bold&quot; border-radius=&quot;4px&quot; padding=&quot;15px 30px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .headline {
#         text-transform: uppercase;
#         letter-spacing: 3px;
#         font-size: 14px !important;
#       }
#       .artistic-title {
#         font-family: &#x27;Playfair Display&#x27;, Georgia, serif !important;
#         font-weight: 300;
#       }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#faf8f5&quot;&gt;
#
#     &lt;mj-section padding=&quot;40px 20px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#8b7355&quot; css-class=&quot;headline&quot; font-size=&quot;14px&quot;&gt;Portsmouth, New Hampshire&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;48px&quot; color=&quot;#2c3e50&quot; css-class=&quot;artistic-title&quot; padding=&quot;10px 0&quot;&gt;
#           Annual Quilt&lt;br/&gt;Creation Event
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;20px&quot; color=&quot;#7f8c8d&quot; font-style=&quot;italic&quot; padding=&quot;0 0 20px 0&quot;&gt;
#           Where threads connect communities
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;0 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; alt=&quot;Quilting patterns and designs&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;40px 20px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot;&gt;
#         &lt;mj-text font-size=&quot;24px&quot; color=&quot;#d35400&quot; padding-bottom=&quot;15px&quot;&gt;
#           For Every Skill Level
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           Whether you&#x27;re threading your first needle or have decades of quilting mastery, our annual event welcomes you with open arms. Share techniques, learn new patterns, and be part of something beautiful.
#         &lt;/jj-text&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;left&quot; padding-top=&quot;20px&quot;&gt;
#           Reserve Your Spot
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/EZItMmj9aQSE.png&quot; alt=&quot;Quilting detail&quot; padding=&quot;0 0 0 20px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#2c3e50&quot; padding=&quot;50px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;32px&quot; padding-bottom=&quot;20px&quot;&gt;
#           3 Days • 50+ Quilters • Infinite Creativity
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ecf0f1&quot; font-size=&quot;18px&quot;&gt;
#           Join us for workshops, collaborative projects, and the grand reveal of our community quilt — a tapestry woven from the hearts of Portsmouth quilters.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-wrapper padding=&quot;40px 20px&quot; background-color=&quot;#ffffff&quot;&gt;
#       &lt;mj-section padding=&quot;0&quot;&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/IE9az4JoGS-J.png&quot; alt=&quot;Quilting workshop&quot; padding=&quot;10px&quot; /&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#d35400&quot; padding-top=&quot;10px&quot;&gt;
#             Hands-On Workshops
#           &lt;/mj-text&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot;&gt;
#             Master new techniques with expert instructors
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/hA2OiBty-zz0.png&quot; alt=&quot;Quilting patterns&quot; padding=&quot;10px&quot; /&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#d35400&quot; padding-top=&quot;10px&quot;&gt;
#             Pattern Exchange
#           &lt;/mj-text&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot;&gt;
#             Share and discover unique designs
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; alt=&quot;Community gathering&quot; padding=&quot;10px&quot; /&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; color=&quot;#d35400&quot; padding-top=&quot;10px&quot;&gt;
#             Community Creation
#           &lt;/mj-text&gt;
#           &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot;&gt;
#             Contribute to our collective masterpiece
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-section&gt;
#     &lt;/mj-wrapper&gt;
#
#     &lt;mj-section padding=&quot;40px 20px 20px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;28px&quot; color=&quot;#2c3e50&quot; padding-bottom=&quot;25px&quot;&gt;
#           Begin Your Quilting Journey
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; font-size=&quot;18px&quot; padding=&quot;20px 40px&quot;&gt;
#           Register Today
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; padding-top=&quot;20px&quot; font-size=&quot;14px&quot; color=&quot;#7f8c8d&quot;&gt;
#           Limited spaces available • Materials provided • All experience levels welcome
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;30px 20px&quot; background-color=&quot;#f5f3f0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#8b7355&quot;&gt;
#           Questions? Contact us at quilts@portsmouthcreates.org&lt;br/&gt;
#           Portsmouth Community Center • 123 Harbor Street
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#   &lt;/mj-body&gt;
# &lt;/mjml&gt;</div>
#             </div>
#         </div>
#         <div style="flex:0 0 450px;">
#             <div style="font-size:16pt; font-weight:bold; text-align:left;">Email Design</div>
#             <img src="generated_emails/craft store/2025-08-26 14:56:10.230248/screenshot.png" style="width:450px; border:1px solid #ddd; border-radius:4px;">
#         </div>
#     </div>

# %%
## Testing GPT-5 (low reasoning effort)
 
for test_case, prompt in [
    ['coffee', 'customer welcome email. start with introducing our new collection of espresso machines. Then add more about us below that.'], 
    ['seafood', 'focus of the email should be the chilean seabass recipe section. Come up with an interesting way to show this. Then include a note to sign up for text alerts below that'],
    ['craft store','annual create a quilt event. Bringing together novice and advanced quilters from around Portsmouth NH to create beautiful new designs.']
]:
    for _ in range(2): 
        output_text = test_prompts.generate_emails_from_prompt(
            system_prompt=EMAIL_SYSTEM_PROMPT_BASIC, 
            test_case=test_case,
            creative_brief=prompt,
            has_plan_step_in_output=False,
            provider="openai"
        )
# Out:
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; color=&quot;#222222&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#1A1A1A&quot; color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; inner-padding=&quot;16px 28px&quot; font-weight=&quot;700&quot; border-radius=&quot;6px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700;800&amp;display=swap&quot; /&gt;
#     &lt;mj-preview&gt;Welcome — meet our new espresso collection + the story behind our craft&lt;/mj-preview&gt;
#     &lt;mj-style&gt;
#       .eyebrow { letter-spacing: 0.12em; text-transform: uppercase; font-weight: 700; font-size: 12px; color: #8A8A8A; }
#       .pill { display:inline-block; padding:6px 10px; border-radius:999px; background:#F2F2F2; font-size:12px; color:#555; font-weight:600; }
#       .shadow-card { box-shadow: 0 8px 24px rgba(0,0,0,0.08); border-radius: 12px; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FAFAFA&quot;&gt;
#     &lt;!-- Header / Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;48px 0 56px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;8px 24px&quot;&gt;
#           &lt;span class=&quot;pill&quot;&gt;Welcome to the bar&lt;/span&gt;
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;34px&quot; font-weight=&quot;800&quot; color=&quot;#111111&quot; padding=&quot;8px 24px&quot;&gt;
#           Meet the New Espresso Collection
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#333333&quot; padding=&quot;8px 24px 20px&quot;&gt;
#           Hand-built machines. Precision control. Café-quality shots—now at home.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/collections/espresso&quot; align=&quot;center&quot;&gt;
#           Explore Collection
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Feature grid --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;36px 16px 8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca dual boiler espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding=&quot;14px 0 4px&quot;&gt;Bianca&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#555555&quot; padding=&quot;0 0 10px&quot;&gt;Dual-boiler mastery with paddle profiling for barista-level control.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/products/bianca&quot; background-color=&quot;#111111&quot;&gt;Shop Bianca&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX heat exchange espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding=&quot;14px 0 4px&quot;&gt;MaraX&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#555555&quot; padding=&quot;0 0 10px&quot;&gt;Compact footprint. Silent performance. Sweet-spot shots, every time.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/products/marax&quot; background-color=&quot;#111111&quot;&gt;Shop MaraX&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding=&quot;14px 0 4px&quot;&gt;Elizabeth&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#555555&quot; padding=&quot;0 0 10px&quot;&gt;Fast heat-up, PID precision, and silky milk texture on demand.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/products/elizabeth&quot; background-color=&quot;#111111&quot;&gt;Shop Elizabeth&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Highlight banner --&gt;
#     &lt;mj-section background-color=&quot;#111111&quot; padding=&quot;24px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-weight=&quot;700&quot; font-size=&quot;20px&quot; padding-bottom=&quot;6px&quot;&gt;Launch Perks&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#EDEDED&quot; font-size=&quot;14px&quot;&gt;
#           Free barista setup call + 30‑day brew‑love guarantee + extended 2‑year warranty on new collection
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Story / About Us --&gt;
#     &lt;mj-section background-url=&quot;/uploads/about-us-manifesto.png&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;0&quot; text-align=&quot;left&quot;&gt;
#       &lt;mj-column background-color=&quot;rgba(255,255,255,0.94)&quot; padding=&quot;40px 24px&quot;&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot;&gt;About us&lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;26px&quot; font-weight=&quot;800&quot; color=&quot;#111111&quot; padding=&quot;6px 0 8px&quot;&gt;Built by people who obsess over the last drop&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#333333&quot;&gt;
#           We’re a team of engineers, roasters, and home baristas designing tools that honor the ritual. Every machine we carry is tested in‑house for temperature stability, ergonomics, and cup quality—so you can focus on flavor, not guesswork.
#         &lt;/mj-text&gt;
#         &lt;mj-spacer height=&quot;8px&quot; /&gt;
#         &lt;mj-text color=&quot;#333333&quot;&gt;
#           From first dial‑in to latte art, we’ll be with you every step: brew guides, responsive support, and real humans behind the inbox.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/about&quot; background-color=&quot;#1A1A1A&quot; align=&quot;left&quot;&gt;Learn Our Story&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Persona / Team callout --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;28px 16px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/Melanie.webp&quot; alt=&quot;Your personal coffee concierge&quot; border-radius=&quot;12px&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding-bottom=&quot;6px&quot;&gt;Need a recommendation?&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#555555&quot; padding-bottom=&quot;10px&quot;&gt;Tell us your space, beans, and milk routine—we’ll match you to the right setup.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/quiz&quot; background-color=&quot;#3D3D3D&quot;&gt;Take the 2‑minute quiz&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Social proof / DNA --&gt;
#     &lt;mj-section background-color=&quot;#F4F4F4&quot; padding=&quot;2
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; color=&quot;#222222&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button background-color=&quot;#1C3C3C&quot; color=&quot;#ffffff&quot; inner-padding=&quot;14px 22px&quot; font-weight=&quot;700&quot; border-radius=&quot;4px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;800&amp;display=swap&quot; /&gt;
#     &lt;mj-preview&gt;Welcome — Meet our new espresso collection + our story&lt;/mj-preview&gt;
#     &lt;mj-style&gt;
#       .eyebrow { letter-spacing: 0.12em; text-transform: uppercase; color: #1C3C3C; font-size:12px; font-weight:700 }
#       .subtle { color:#6A7381 }
#       .divider { border-top:1px solid #E6EBF1 }
#       .kicker { font-weight:700; color:#1C3C3C }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FAFCFB&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;48px 20px 60px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;eyebrow&quot;&gt;Welcome to the ritual&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;32px&quot; font-weight=&quot;800&quot; color=&quot;#0E141B&quot; padding-bottom=&quot;6px&quot;&gt;Introducing our new espresso collection&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#24313A&quot; font-size=&quot;18px&quot; padding-bottom=&quot;18px&quot;&gt;
#           Precision-engineered machines for café-quality shots at home. Designed to be dialed in, day after day.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/collection&quot; align=&quot;center&quot;&gt;
#           Explore the Collection
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#6A7381&quot; font-size=&quot;13px&quot; padding-top=&quot;10px&quot;&gt;
#           Members save 10% on accessories with any machine purchase.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Product highlight row --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;28px 20px 8px&quot;&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca espresso machine with wooden accents&quot; padding-bottom=&quot;10px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot;&gt;Bianca&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;Flow control, dual boiler, barista-grade profiling.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/bianca&quot; background-color=&quot;#0E6B5B&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot;&gt;Shop Bianca&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX compact heat-exchange espresso machine&quot; padding-bottom=&quot;10px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot;&gt;MaraX&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;Compact footprint, silent performance, instant steam.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/marax&quot; background-color=&quot;#0E6B5B&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot;&gt;Shop MaraX&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth dual boiler espresso machine&quot; padding-bottom=&quot;10px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot;&gt;Elizabeth&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;Dual boiler speed, PID stability, everyday ease.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/elizabeth&quot; background-color=&quot;#0E6B5B&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot;&gt;Shop Elizabeth&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Feature band --&gt;
#     &lt;mj-section background-color=&quot;#F2F6F4&quot; padding=&quot;22px 20px 26px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;700&quot; color=&quot;#1C3C3C&quot;&gt;Why you’ll love the collection&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px 24px&quot;&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-bottom=&quot;4px&quot;&gt;Dial-in control&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;PID, pre-infusion, and flow profiling for repeatable results.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-bottom=&quot;4px&quot;&gt;Built to last&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;Stainless-steel internals, serviceable parts, and long warranties.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-bottom=&quot;4px&quot;&gt;Counter-friendly&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;subtle&quot; font-size=&quot;14px&quot;&gt;Compact footprints with premium finishes that elevate any kitchen.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Secondary CTA --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;8px 20px 28px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-button href=&quot;https://example.com/compare&quot; align=&quot;center&quot; background-color=&quot;#1C3C3C&quot;&gt;
#           Compare Models
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About us intro --&gt;
#     &lt;mj-section background-color=&quot;#0E141B&quot; padding=&quot;40px 20px 32px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#8BE0C7&quot; css-class=&quot;eyebrow&quot;&gt;About us&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;26px&quot; font-weight=&quot;800&quot; padding-bottom=&quot;10px&quot;&gt;We’re obsessed with better mornings&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#D8E2E9&quot; font-size=&quot;16px&quot; padding-bottom=&quot;18px&quot;&gt;
#           We started as home baristas who wanted café-quality coffee without compromise. Today, we curate machines we trust, test every product in-house, and back it with real support.
#         &lt;/mj-text&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; alt=&quot;Our manifesto&quot; width=&quot;420px&quot; align=&quot;center&quot; padding-bottom=&quot;16px&quot; /&gt;
#         &lt;mj-button href=&quot;https://example.com/a
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; color=&quot;#1a1a1a&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button font-size=&quot;16px&quot; font-weight=&quot;700&quot; background-color=&quot;#0C6&quot; color=&quot;#ffffff&quot; inner-padding=&quot;14px 22px&quot; border-radius=&quot;8px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .eyebrow{letter-spacing:.12em;text-transform:uppercase;color:#0C6;font-size:12px;font-weight:700;}
#       .card{border-radius:16px;overflow:hidden;box-shadow:0 8px 28px rgba(0,0,0,.12);}
#       .tag{display:inline-block;background:#E6FFF4;color:#0C6;border-radius:999px;padding:6px 10px;font-size:12px;font-weight:700;letter-spacing:.03em;}
#       .steps ol{margin:0;padding-left:18px;}
#       .steps li{margin:8px 0;}
#       .pill-cta{background:#0C6;color:#fff;border-radius:999px;padding:12px 22px;font-weight:700;text-decoration:none;}
#       .mute{color:#6b7280;}
#       .divider{height:1px;background:#e5e7eb;}
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f8fafc&quot;&gt;
#     &lt;!-- Header --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;16px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; alt=&quot;Brand wordmark&quot; align=&quot;left&quot; padding=&quot;8px 24px&quot; width=&quot;180px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Hero: Recipe Spotlight with layered recipe card over image --&gt;
#     &lt;mj-section background-url=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;48px 0 72px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 24px&quot; css-class=&quot;eyebrow&quot;&gt;Recipe Spotlight&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;34px&quot; font-weight=&quot;800&quot; color=&quot;#ffffff&quot; padding=&quot;6px 24px&quot;&gt;
#           Chilean Sea Bass, Citrus-Miso Glaze
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#E6FFF4&quot; padding=&quot;0 24px 24px&quot;&gt;
#           A silky, restaurant-level dish you can finish in under 25 minutes.
#         &lt;/mj-text&gt;
#         &lt;mj-wrapper padding=&quot;0 24px&quot;&gt;
#           &lt;mj-section background-color=&quot;#ffffff&quot; border-radius=&quot;16px&quot; css-class=&quot;card&quot; padding=&quot;0&quot;&gt;
#             &lt;mj-column vertical-align=&quot;middle&quot;&gt;
#               &lt;mj-image src=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; alt=&quot;Seared Chilean sea bass with citrus-miso glaze on a skillet&quot; padding=&quot;0&quot; border-radius=&quot;16px 16px 0 0&quot; /&gt;
#               &lt;mj-text padding=&quot;16px 24px 8px&quot; font-size=&quot;18px&quot; font-weight=&quot;700&quot;&gt;
#                 What you&#x27;ll need
#               &lt;/mj-text&gt;
#               &lt;mj-text padding=&quot;0 24px 16px&quot; color=&quot;#374151&quot;&gt;
#                 Chilean sea bass (2 x 6oz), white miso, orange + lime, honey, soy, garlic, ginger, sesame oil, butter, scallions, toasted sesame, sea salt.
#               &lt;/mj-text&gt;
#               &lt;mj-divider border-color=&quot;#e5e7eb&quot; padding=&quot;0 24px&quot; /&gt;
#               &lt;mj-group&gt;
#                 &lt;mj-column width=&quot;100%&quot;&gt;
#                   &lt;mj-text padding=&quot;16px 24px 0&quot; font-size=&quot;18px&quot; font-weight=&quot;700&quot;&gt;Cook-along: 5 steps&lt;/mj-text&gt;
#                   &lt;mj-text padding=&quot;8px 24px 16px&quot; css-class=&quot;steps&quot;&gt;
#                     &lt;ol&gt;
#                       &lt;li&gt;Pat fish dry, season with salt. Mix glaze: 1 tbsp white miso, 1 tbsp honey, 1 tbsp soy, 1 tbsp orange juice, 1 tsp lime juice, 1 tsp grated ginger, 1 tsp minced garlic.&lt;/li&gt;
#                       &lt;li&gt;Sear bass in 1 tbsp neutral oil, skin-side down, medium-high, 3–4 min to crisp.&lt;/li&gt;
#                       &lt;li&gt;Flip, add 1 tbsp butter and half the glaze; baste 1–2 min.&lt;/li&gt;
#                       &lt;li&gt;Transfer to 400°F oven 5–7 min until just opaque and flakes.&lt;/li&gt;
#                       &lt;li&gt;Return to stovetop, brush remaining glaze, finish with lime zest, scallions, sesame.&lt;/li&gt;
#                     &lt;/ol&gt;
#                   &lt;/mj-text&gt;
#                 &lt;/mj-column&gt;
#               &lt;/mj-group&gt;
#               &lt;mj-text padding=&quot;0 24px 16px&quot;&gt;
#                 &lt;span class=&quot;tag&quot;&gt;Bright &amp; Buttery&lt;/span&gt;
#                 &lt;span class=&quot;tag&quot; style=&quot;margin-left:8px;&quot;&gt;25 Minutes&lt;/span&gt;
#                 &lt;span class=&quot;tag&quot; style=&quot;margin-left:8px;&quot;&gt;Weeknight Fancy&lt;/span&gt;
#               &lt;/mj-text&gt;
#               &lt;mj-button href=&quot;https://example.com/recipes/chilean-sea-bass-citrus-miso&quot; padding=&quot;8px 24px 24px&quot; align=&quot;center&quot;&gt;
#                 Get Full Recipe &amp; Tips
#               &lt;/mj-button&gt;
#             &lt;/mj-column&gt;
#           &lt;/mj-section&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Optional: Pairing &amp; Pro tip row --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;24px&quot;&gt;
#       &lt;mj-column width=&quot;66%&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding=&quot;0 0 8px&quot;&gt;Pro tip&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;mute&quot; padding=&quot;0&quot;&gt;Score the skin with shallow slashes to prevent curling and get ultra-crisp results. Let the fish rest 3 minutes before plating.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;34%&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; padding=&quot;0 0 8px&quot;&gt;Pair it with&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;mute&quot; padding=&quot;0&quot;&gt;Chilled Chardonnay or jasmine rice + blistered asparagus.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Sticky-style CTA stripe --&gt;
#     &lt;mj-section background-color=&quot;#0C6&quot; padding=&quot;18px 24px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text color=&quot;#DCFFF2&quot; font-weight=&quot;700&quot; padding=&quot;0 0 6px&quot;&gt;Ready to cook tonight?&lt;/mj-text&gt;
#         &lt;mj-button background-color=&quot;#ffffff&quot; color=&quot;#0C6&quot; href=&quot;https://example.com/shop/sea-bass&quot; align=&quot;left&quot;&gt;Shop Chilean Sea Bass&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Text Alerts signup note --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;28px 24px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot; padding=&quot;0 0 4px&quot;&gt;Never miss a drop&lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;20px&quot; font-weight=&quot;800&quot; padding=&quot;0 0 8px&quot;&gt;Sign up for text alerts&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;mute&quot; padding=&quot;0 0 14px&quot;&gt;
#           Get early access to fresh catch alerts, limited-time offers, and new recipes sent straight to your phone.
#         &lt;/
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-title&gt;Chef’s Spotlight: Chilean Sea Bass, 3 Ways&lt;/mj-title&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;800&amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, -apple-system, Segoe UI, Roboto, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#1b1b1b&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#       &lt;mj-button background-color=&quot;#0A6CF1&quot; color=&quot;#ffffff&quot; padding=&quot;0px&quot; inner-padding=&quot;14px 24px&quot; border-radius=&quot;8px&quot; font-weight=&quot;700&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .eyebrow { letter-spacing: .12em; text-transform: uppercase; color:#0A6CF1; font-weight:700; font-size:12px; }
#       .card { box-shadow: 0 10px 30px rgba(10,30,60,.08); border-radius: 14px; overflow:hidden; }
#       .pill { display:inline-block; background:#E8F0FE; color:#0A45B8; font-weight:700; font-size:12px; padding:6px 10px; border-radius:999px; }
#       .kicker { color:#5b6b7b; font-size:14px; }
#       .divider { border-top:1px solid #E8ECF3; }
#       .step { font-weight:700; color:#0A45B8; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#F7F9FC&quot;&gt;
#     &lt;!-- Hero: Immersive Recipe Spotlight --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; padding=&quot;0&quot; background-url=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot;&gt;
#       &lt;mj-column padding=&quot;48px 24px 56px&quot;&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot;&gt;Chef’s Spotlight&lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;34px&quot; font-weight=&quot;800&quot; color=&quot;#ffffff&quot; line-height=&quot;1.15&quot;&gt;
#           Chilean Sea Bass, Elevated
#         &lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#ECF2FF&quot; font-size=&quot;16px&quot; padding-bottom=&quot;20px&quot;&gt;
#           Melt-in-your-mouth texture meets bright, coastal flavors. Try our signature method, or remix it two more ways—pan, oven, or miso-glazed.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/sea-bass-recipe&quot; background-color=&quot;#ffffff&quot; color=&quot;#0A6CF1&quot;&gt;
#           Cook This Tonight
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Recipe Split: Visual Timeline --&gt;
#     &lt;mj-section background-color=&quot;#F7F9FC&quot; padding=&quot;28px 0 8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; alt=&quot;Wave divider&quot; padding=&quot;0 24px 8px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#ffffff&quot; css-class=&quot;card&quot; padding=&quot;0 16px 28px&quot;&gt;
#       &lt;mj-column padding=&quot;24px 24px 8px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;pill&quot;&gt;15 minutes active • Serves 2&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;26px&quot; font-weight=&quot;800&quot; padding-top=&quot;10px&quot;&gt;
#           The Core Method: Crispy-Skinned Chilean Sea Bass
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; class=&quot;kicker&quot; padding-bottom=&quot;12px&quot;&gt;
#           A “visual timeline” recipe—scan left to right and cook along.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#
#       &lt;!-- Timeline Row --&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/BL-jOWEdyIYp.jpg&quot; alt=&quot;Pat dry &amp; season&quot; padding=&quot;0 18px&quot; border-radius=&quot;10px&quot; /&gt;
#           &lt;mj-text padding=&quot;8px 18px 0&quot;&gt;
#             &lt;span class=&quot;step&quot;&gt;01 • Prep&lt;/span&gt;&lt;br /&gt;
#             Pat fillets dry. Season skin well with salt; lightly oil flesh. Preheat pan to hot-but-not-smoking.
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; alt=&quot;Sear skin-side down&quot; padding=&quot;0 18px&quot; border-radius=&quot;10px&quot; /&gt;
#           &lt;mj-text padding=&quot;8px 18px 0&quot;&gt;
#             &lt;span class=&quot;step&quot;&gt;02 • Sear&lt;/span&gt;&lt;br /&gt;
#             Add neutral oil. Lay fish skin-side down. Press gently for 20–30s. Sear 5–7 min until skin is glassy-crisp.
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;33%&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; alt=&quot;Butter baste &amp; finish&quot; padding=&quot;0 18px&quot; border-radius=&quot;10px&quot; /&gt;
#           &lt;mj-text padding=&quot;8px 18px 0&quot;&gt;
#             &lt;span class=&quot;step&quot;&gt;03 • Finish&lt;/span&gt;&lt;br /&gt;
#             Flip, add 1 tbsp butter, thyme, and a squeeze of lemon. Baste 30–60s. Rest 2 min. Skin stays shatter-crisp.
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#
#       &lt;!-- Ingredients + Pro Tips --&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column width=&quot;50%&quot; padding=&quot;8px 24px&quot;&gt;
#           &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot;&gt;You’ll Need&lt;/mj-text&gt;
#           &lt;mj-text&gt;
#             • 2 Chilean sea bass fillets (6–7 oz each)&lt;br /&gt;
#             • Kosher salt &amp; black pepper&lt;br /&gt;
#             • Neutral oil (avocado or grapeseed)&lt;br /&gt;
#             • 1 tbsp unsalted butter&lt;br /&gt;
#             • Lemon wedges, fresh thyme
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column width=&quot;50%&quot; padding=&quot;8px 24px&quot;&gt;
#           &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot;&gt;Pro Tips&lt;/mj-text&gt;
#           &lt;mj-text&gt;
#             • Dry skin = crisp skin. Paper towels are your friend.&lt;br /&gt;
#             • Don’t chase the fish—let it release naturally when skin is rendered.&lt;br /&gt;
#             • Aim for medium: flaky edges, custardy center.
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#
#       &lt;mj-column padding=&quot;12px 24px 0&quot;&gt;
#         &lt;mj-button href=&quot;https://example.com/sea-bass-recipe#core&quot; align=&quot;center&quot;&gt;View Full Step-by-Step&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Remix Row: 2 More Ways --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 0 24px&quot; css-class=&quot;card&quot;&gt;
#       &lt;mj-column padding=&quot;24px&quot;&gt;
#         &lt;mj-text font-size=&quot;20px&quot; font-weight=&quot;800&quot;&gt;Remix It&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;0 24px 24px&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/NoUihF8gfITs.png&quot; alt=&quot;Miso glazed sea bass&quot; padding=&quot;0 0 10px&quot; /&gt;
#           &lt;mj-text&gt;
#             &lt;span class=&quot;step&quot;&gt;Miso-Glazed&lt;/span&gt; — Whisk white miso, mirin, sake, honey. Marinate 30 min, bake at 400°F for 10–12 min. Finish under broiler 1–2 min for lacquer.
#           &lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column padding=&quot;0 24px 24px&qu
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Portsmouth’s Annual Create-a-Quilt | Stitch, share, and design together&lt;/mj-preview&gt;
#     &lt;mj-font name=&quot;Poppins&quot; href=&quot;https://fonts.googleapis.com/css2?family=Poppins:wght@400;600;700&amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Poppins, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2B2B2B&quot; font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button background-color=&quot;#D94F70&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; inner-padding=&quot;14px 24px&quot; border-radius=&quot;6px&quot; font-weight=&quot;700&quot; /&gt;
#       &lt;mj-section padding=&quot;0&quot; /&gt;
#       &lt;mj-column padding=&quot;0&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .eyebrow { letter-spacing: 2px; text-transform: uppercase; color: #D94F70; font-weight: 700; }
#       .card { border: 1px solid #EEE; border-radius: 10px; }
#       .tag { background:#FCE8EE; color:#C43C60; padding:4px 10px; border-radius:20px; font-size:12px; font-weight:700; display:inline-block; }
#       .divider { border-top:1px dashed #D7D7D7; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFF9F7&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;40px 0 60px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;eyebrow&quot;&gt;Community Event&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;38px&quot; color=&quot;#1A1A1A&quot; font-weight=&quot;700&quot; padding-bottom=&quot;6px&quot;&gt;Annual Create‑a‑Quilt&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#4A4A4A&quot; font-size=&quot;18px&quot; padding-bottom=&quot;22px&quot;&gt;Bringing together novice and advanced quilters across Portsmouth, NH to craft beautiful new designs—one stitch at a time.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/register&quot; align=&quot;center&quot;&gt;Reserve Your Spot&lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#7A7A7A&quot; font-size=&quot;13px&quot; padding-top=&quot;10px&quot;&gt;Limited seats | All skill levels welcome&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Event Details --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;28px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text css-class=&quot;tag&quot;&gt;What to expect&lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;22px&quot; font-weight=&quot;700&quot; padding-top=&quot;8px&quot;&gt;Design. Stitch. Share.&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Join a vibrant day of quilting circles, mini‑workshops, pattern swaps, and collaborative blocks. Bring your favorite fabric, or dive into our community stash. Leave with fresh techniques, new friends, and a piece of a community quilt that we’ll display downtown.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Cards: When / Where / Who --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px 10px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/EZItMmj9aQSE.png&quot; alt=&quot;Calendar icon&quot; padding=&quot;0 0 8px&quot; width=&quot;56px&quot; /&gt;
#           &lt;mj-text font-weight=&quot;700&quot;&gt;When&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Saturday, October 19 • 10:00 AM – 4:00 PM&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; alt=&quot;Map pin icon&quot; padding=&quot;0 0 8px&quot; width=&quot;56px&quot; /&gt;
#           &lt;mj-text font-weight=&quot;700&quot;&gt;Where&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Portsmouth Quilt Hall • 55 Market St, Portsmouth, NH&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; alt=&quot;People icon&quot; padding=&quot;0 0 8px&quot; width=&quot;56px&quot; /&gt;
#           &lt;mj-text font-weight=&quot;700&quot;&gt;Who&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Novice to advanced quilters. Kids 12+ welcome with an adult.&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Visual Break --&gt;
#     &lt;mj-section background-color=&quot;#FFF1F4&quot; padding=&quot;0 20px 30px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/6w0BvmNX9G7t.png&quot; alt=&quot;Colorful quilt textures&quot; padding=&quot;20px 0 0&quot; border-radius=&quot;12px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Workshops &amp; Activities --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;24px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text css-class=&quot;tag&quot;&gt;Workshops &amp; Activities&lt;/mj-text&gt;
#         &lt;mj-wrapper padding=&quot;10px 0&quot;&gt;
#           &lt;mj-section background-color=&quot;#ffffff&quot; css-class=&quot;card&quot; padding=&quot;16px&quot;&gt;
#             &lt;mj-column width=&quot;26%&quot;&gt;
#               &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; alt=&quot;Patchwork icon&quot; padding=&quot;0&quot; width=&quot;80px&quot; /&gt;
#             &lt;/mj-column&gt;
#             &lt;mj-column width=&quot;74%&quot;&gt;
#               &lt;mj-text font-weight=&quot;700&quot;&gt;Modern Patchwork Lab&lt;/mj-text&gt;
#               &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Explore color play, improv piecing, and bold geometrics guided by local artists.&lt;/mj-text&gt;
#             &lt;/mj-column&gt;
#           &lt;/mj-section&gt;
#           &lt;mj-section background-color=&quot;#ffffff&quot; css-class=&quot;card&quot; padding=&quot;16px&quot;&gt;
#             &lt;mj-column width=&quot;26%&quot;&gt;
#               &lt;mj-image src=&quot;/uploads/hA2OiBty-zz0.png&quot; alt=&quot;Hand quilting icon&quot; padding=&quot;0&quot; width=&quot;80px&quot; /&gt;
#             &lt;/mj-column&gt;
#             &lt;mj-column width=&quot;74%&quot;&gt;
#               &lt;mj-text font-weight=&quot;700&quot;&gt;Hand‑Quilting Circle&lt;/mj-text&gt;
#               &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Slow stitching techniques, sashiko basics, and meditative textures.&lt;/mj-text&gt;
#             &lt;/mj-column&gt;
#           &lt;/mj-section&gt;
#           &lt;mj-section background-color=&quot;#ffffff&quot; css-class=&quot;card&quot; padding=&quot;16px&quot;&gt;
#             &lt;mj-column width=&quot;26%&quot;&gt;
#               &lt;mj-image src=&quot;/uploads/ZWonHtct7o2E.png&quot; alt=&quot;Swap icon&quot; padding=&quot;0&quot; width=&quot;80px&quot; /&gt;
#             &lt;/mj-column&gt;
#             &lt;mj-column width=&quot;74%&quot;&gt;
#               &lt;mj-text font-weight=&quot;700&quot;&gt;Pattern &amp; Fabric Swap&lt;/mj-text&gt;
#               &lt;mj-text color=&quot;#5B5B5B&quot;&gt;Bring a fat quarter or pattern you’re ready to trade. Discover something new.&lt;/mj-text&gt;
#             &lt;/mj-column&gt;
#           &lt;/mj-section&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2A2A2A&quot; font-size=&quot;16px&quot; line-height=&quot;1.5&quot; /&gt;
#       &lt;mj-button background-color=&quot;#CB2B6B&quot; color=&quot;#ffffff&quot; font-weight=&quot;700&quot; inner-padding=&quot;14px 24px&quot; border-radius=&quot;6px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Poppins&quot; href=&quot;https://fonts.googleapis.com/css2?family=Poppins:wght@400;600;700&amp;display=swap&quot; /&gt;
#     &lt;mj-style&gt;
#       .eyebrow { letter-spacing: 1.8px; text-transform: uppercase; color: #CB2B6B; font-weight: 700; }
#       .overlap-card { box-shadow: 0 12px 24px rgba(0,0,0,0.08); border-radius: 12px; }
#       .divider { border-top: 2px dashed #E5E5E5; height: 2px; }
#       .chip { background:#F9E5EE; color:#9B1247; padding:6px 10px; border-radius:20px; font-size:13px; font-weight:600; display:inline-block; }
#       .muted { color:#6B7280; }
#       .grid-title { font-weight:700; font-size:18px; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFFDF9&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/q1rNLeA5MGW4.png&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;0&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/bHyb-RbQe-aY.jpg&quot; alt=&quot;Portsmouth Quilt Collective&quot; width=&quot;150px&quot; padding=&quot;24px&quot; align=&quot;left&quot; /&gt;
#         &lt;mj-spacer height=&quot;18px&quot; /&gt;
#         &lt;mj-text font-family=&quot;Poppins, Helvetica, Arial, sans-serif&quot; align=&quot;left&quot; padding=&quot;0 24px&quot;&gt;
#           &lt;span class=&quot;eyebrow&quot;&gt;Portsmouth, NH&lt;/span&gt;
#         &lt;/mj-text&gt;
#         &lt;mj-text font-family=&quot;Poppins, Helvetica, Arial, sans-serif&quot; font-weight=&quot;700&quot; font-size=&quot;36px&quot; color=&quot;#14213D&quot; padding=&quot;6px 24px 8px&quot;&gt;
#           Annual Create‑A‑Quilt Event
#         &lt;/mj-text&gt;
#         &lt;mj-text font-size=&quot;18px&quot; color=&quot;#273043&quot; padding=&quot;0 24px 18px&quot;&gt;
#           A colorful day stitching together community, creativity, and new designs—open to novices and advanced quilters alike.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/register&quot; align=&quot;left&quot; padding=&quot;0 24px 28px&quot;&gt;
#           Save My Spot
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Floating card with key details --&gt;
#     &lt;mj-section background-color=&quot;#FFFDF9&quot; padding-top=&quot;0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-wrapper padding=&quot;0 24px&quot;&gt;
#           &lt;mj-section background-color=&quot;#FFFFFF&quot; border-radius=&quot;12px&quot; css-class=&quot;overlap-card&quot;&gt;
#             &lt;mj-column width=&quot;33%&quot;&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;18px 12px 6px&quot; font-weight=&quot;700&quot;&gt;Date&lt;/mj-text&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;0 12px 18px&quot; class=&quot;muted&quot;&gt;Saturday, Oct 19 • 9am–4pm&lt;/mj-text&gt;
#             &lt;/mj-column&gt;
#             &lt;mj-column width=&quot;34%&quot;&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;18px 12px 6px&quot; font-weight=&quot;700&quot;&gt;Location&lt;/mj-text&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;0 12px 18px&quot; class=&quot;muted&quot;&gt;Portsmouth Community Center&lt;/mj-text&gt;
#             &lt;/mj-column&gt;
#             &lt;mj-column width=&quot;33%&quot;&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;18px 12px 6px&quot; font-weight=&quot;700&quot;&gt;Tickets&lt;/mj-text&gt;
#               &lt;mj-text align=&quot;center&quot; padding=&quot;0 12px 12px&quot; class=&quot;muted&quot;&gt;$25 general • $15 student/senior&lt;/mj-text&gt;
#               &lt;mj-button href=&quot;https://example.com/register&quot; background-color=&quot;#14213D&quot; inner-padding=&quot;10px 18px&quot; font-size=&quot;14px&quot;&gt;Register&lt;/mj-button&gt;
#             &lt;/mj-column&gt;
#           &lt;/mj-section&gt;
#         &lt;/mj-wrapper&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- What to expect + image --&gt;
#     &lt;mj-section padding=&quot;28px 24px&quot;&gt;
#       &lt;mj-column width=&quot;60%&quot;&gt;
#         &lt;mj-text font-family=&quot;Poppins, Helvetica, Arial, sans-serif&quot; font-weight=&quot;700&quot; font-size=&quot;22px&quot; color=&quot;#14213D&quot; padding-bottom=&quot;8px&quot;&gt;
#           Stitch, swap, and learn—your way.
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           - Guided mini-workshops for beginners&lt;br/&gt;
#           - Advanced pattern labs and color theory tips&lt;br/&gt;
#           - Fabric swap table and block exchange wall&lt;br/&gt;
#           - Community quilt build to donate locally&lt;br/&gt;
#           - Pop-up vendors for specialty fabrics and tools
#         &lt;/mj-text&gt;
#         &lt;mj-spacer height=&quot;10px&quot; /&gt;
#         &lt;mj-text class=&quot;muted&quot;&gt;
#           Bring your machine if you have one—limited loaners and cutting stations available. Coffee and light bites provided.
#         &lt;/mj-text&gt;
#         &lt;mj-spacer height=&quot;12px&quot; /&gt;
#         &lt;mj-button href=&quot;https://example.com/schedule&quot; background-color=&quot;#CB2B6B&quot;&gt;See Full Schedule&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;40%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; alt=&quot;Quilters collaborating at tables with colorful fabrics&quot; border-radius=&quot;10px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;0 24px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-width=&quot;0&quot; css-class=&quot;divider&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Skill tracks --&gt;
#     &lt;mj-section padding=&quot;24px 24px 8px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; alt=&quot;Beginner friendly quilting track&quot; border-radius=&quot;10px&quot; padding-bottom=&quot;8px&quot; /&gt;
#         &lt;mj-text class=&quot;grid-title&quot;&gt;Beginner Track&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;muted&quot;&gt;
#           Learn the essentials: cutting, piecing, pressing, and binding. Leave with a finished block and the confidence to keep creating.
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;&lt;span class=&quot;chip&quot;&gt;No experience needed&lt;/span&gt;&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; alt=&quot;Advanced quilting techniques and modern patterns&quot; border-radius=&quot;10px&quot; padding-bottom=&quot;8px&quot; /&gt;
#         &lt;mj-text class=&quot;grid-title&quot;&gt;Advanced Track&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;muted&quot;&gt;
#           Dive into improv curves, foundation paper piecing, and bold colorwork. Trade tips with seasoned makers and push your style.
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;&lt;span class=&quot;chip&quot;&gt;Brin

# %%
## Testing GPT-5 (medium/high reasoning effort)

for reasoning_effort in ["medium", "high"]:
    
    print("TESTING OPEN AI - REASONING EFFORT",   reasoning_effort.upper()) 
    for test_case, prompt in [
        ['coffee', 'customer welcome email. start with introducing our new collection of espresso machines. Then add more about us below that.'], 
        ['seafood', 'focus of the email should be the chilean seabass recipe section. Come up with an interesting way to show this. Then include a note to sign up for text alerts below that'],
        ['craft store','annual create a quilt event. Bringing together novice and advanced quilters from around Portsmouth NH to create beautiful new designs.']
    ]:
        for _ in range(2): 
            output_text = test_prompts.generate_emails_from_prompt(
                system_prompt=EMAIL_SYSTEM_PROMPT_BASIC, 
                test_case=test_case,
                creative_brief=prompt,
                has_plan_step_in_output=False,
                provider="openai",
                reasoning_effort=reasoning_effort
            )
# Out:
# TESTING OPEN AI - REASONING EFFORT MEDIUM
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Welcome—explore our new espresso machine collection and get to know us.&lt;/mj-preview&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, -apple-system, Segoe UI, Roboto, Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; line-height=&quot;1.6&quot; color=&quot;#1f2937&quot; /&gt;
#       &lt;mj-button background-color=&quot;#111827&quot; color=&quot;#ffffff&quot; font-weight=&quot;700&quot; border-radius=&quot;6px&quot; padding=&quot;12px 20px&quot; inner-padding=&quot;12px 24px&quot; /&gt;
#       &lt;mj-divider border-color=&quot;#e5e7eb&quot; border-width=&quot;1px&quot; width=&quot;100%&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .eyebrow { letter-spacing: .12em; text-transform: uppercase; color:#6b7280; font-size:12px; }
#       .h1 { font-size:32px; line-height:1.2; font-weight:800; color:#0b0f19; }
#       .h2 { font-size:22px; line-height:1.3; font-weight:800; color:#0b0f19; }
#       .caption { font-size:13px; color:#6b7280; }
#       .card { border:1px solid #e5e7eb; border-radius:14px; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#f9fafb&quot;&gt;
#     &lt;!-- Header --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;18px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;18px&quot; font-weight=&quot;800&quot; color=&quot;#0b0f19&quot;&gt;Your Brand&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column vertical-align=&quot;middle&quot;&gt;
#         &lt;mj-text align=&quot;right&quot; color=&quot;#6b7280&quot; font-size=&quot;13px&quot;&gt;Brew better at home&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Hero: New Collection --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; padding=&quot;0&quot;&gt;
#       &lt;mj-column padding=&quot;48px 24px 56px&quot; background-color=&quot;#ffffff&quot; border-radius=&quot;0 0 0 0&quot;&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot;&gt;Welcome to the community&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;h1&quot;&gt;Introducing our new espresso machine collection&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#374151&quot;&gt;
#           From first shot to final sip, discover machines engineered for control, consistency, and café‑quality flavor at home.
#         &lt;/mj-text&gt;
#         &lt;mj-group&gt;
#           &lt;mj-column width=&quot;60%&quot;&gt;
#             &lt;mj-button href=&quot;#&quot; align=&quot;left&quot;&gt;Shop the collection&lt;/mj-button&gt;
#           &lt;/mj-column&gt;
#           &lt;mj-column width=&quot;40%&quot;&gt;
#             &lt;mj-button href=&quot;#&quot; background-color=&quot;#ffffff&quot; color=&quot;#111827&quot; border=&quot;1px solid #111827&quot; align=&quot;left&quot;&gt;Compare models&lt;/mj-button&gt;
#           &lt;/mj-column&gt;
#         &lt;/mj-group&gt;
#         &lt;mj-text css-class=&quot;caption&quot; padding-top=&quot;8px&quot;&gt;Free returns within 30 days • Expert support&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Product Grid --&gt;
#     &lt;mj-section background-color=&quot;#f9fafb&quot; padding=&quot;24px 16px 8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text css-class=&quot;h2&quot; align=&quot;center&quot;&gt;Find your perfect fit&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#374151&quot;&gt;
#           Four thoughtfully curated machines—each with its own personality and workflow.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#f9fafb&quot; padding=&quot;0 16px 16px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;12px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot; background-color=&quot;#ffffff&quot; border-radius=&quot;14px&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca espresso machine&quot; padding=&quot;16px 16px 0&quot; border-radius=&quot;12px 12px 0 0&quot; /&gt;
#             &lt;mj-text padding=&quot;12px 16px 0&quot; font-weight=&quot;800&quot;&gt;Bianca&lt;/mj-text&gt;
#             &lt;mj-text padding=&quot;6px 16px 16px&quot; color=&quot;#374151&quot;&gt;
#               Flagship performance with fine-tuned control for the enthusiast.
#             &lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; background-color=&quot;#111827&quot; padding=&quot;0 16px 20px&quot;&gt;Shop Bianca&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#
#         &lt;mj-column padding=&quot;12px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot; background-color=&quot;#ffffff&quot; border-radius=&quot;14px&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth espresso machine&quot; padding=&quot;16px 16px 0&quot; border-radius=&quot;12px 12px 0 0&quot; /&gt;
#             &lt;mj-text padding=&quot;12px 16px 0&quot; font-weight=&quot;800&quot;&gt;Elizabeth&lt;/mj-text&gt;
#             &lt;mj-text padding=&quot;6px 16px 16px&quot; color=&quot;#374151&quot;&gt;
#               Compact, fast, and intuitive—balanced for everyday excellence.
#             &lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; background-color=&quot;#111827&quot; padding=&quot;0 16px 20px&quot;&gt;Shop Elizabeth&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#f9fafb&quot; padding=&quot;0 16px 32px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;12px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot; background-color=&quot;#ffffff&quot; border-radius=&quot;14px&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX espresso machine&quot; padding=&quot;16px 16px 0&quot; border-radius=&quot;12px 12px 0 0&quot; /&gt;
#             &lt;mj-text padding=&quot;12px 16px 0&quot; font-weight=&quot;800&quot;&gt;MaraX&lt;/mj-text&gt;
#             &lt;mj-text padding=&quot;6px 16px 16px&quot; color=&quot;#374151&quot;&gt;
#               Café-style workflow in a sleek footprint; smooth learning curve.
#             &lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; background-color=&quot;#111827&quot; padding=&quot;0 16px 20px&quot;&gt;Shop MaraX&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#
#         &lt;mj-column padding=&quot;12px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot; background-color=&quot;#ffffff&quot; border-radius=&quot;14px&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PESKA01+-+Kate.png&quot; alt=&quot;Kate espresso machine&quot; padding=&quot;16px 16px 0&quot; border-radius=&quot;12px 12px 0 0&quot; /&gt;
#             &lt;mj-text padding=&quot;12px 16px 0&quot; font-weight=&quot;800&quot;&gt;Kate&lt;/mj-text&gt;
#             &lt;mj-text padding=&quot;6px 16px 16px&quot; color=&quot;#374151&quot;&gt;
#               All‑in‑one convenience—streamlined brewing without compromise.
#             &lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; background-color=&quot;#111827&quot; padding=&quot;0 16px 20px&quot;&gt;Shop
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Meet your new daily ritual — our latest espresso collection is here&lt;/mj-preview&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&amp;amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, -apple-system, Segoe UI, Roboto, Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2c2c2c&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#4C2F24&quot; color=&quot;#ffffff&quot; border-radius=&quot;8px&quot; inner-padding=&quot;14px 22px&quot; font-weight=&quot;600&quot; font-size=&quot;16px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .eyebrow { text-transform: uppercase; letter-spacing: .12em; font-size: 12px; color: #7b6a61; }
#       .muted { color: #6b6b6b; }
#       .tag { background:#efe8e2; border-radius:999px; padding:6px 12px; display:inline-block; font-size:13px; color:#6f5b51; }
#       .divider { border-top:1px solid #ece7e2; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FAF7F3&quot;&gt;
#     &lt;!-- Header --&gt;
#     &lt;mj-section background-color=&quot;#FAF7F3&quot; padding=&quot;20px 0 10px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;12px&quot; color=&quot;#7b6a61&quot;&gt;Welcome! You’re on the list for fresh coffee gear, tips, and offers.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Hero: New Collection --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding=&quot;0&quot;&gt;
#       &lt;mj-column padding=&quot;48px 24px 56px&quot; background-color=&quot;rgba(0,0,0,0.35)&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; css-class=&quot;eyebrow&quot;&gt;New Espresso Collection&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;34px&quot; font-weight=&quot;700&quot; line-height=&quot;1.2&quot; padding-bottom=&quot;10px&quot;&gt;Your café, perfected at home&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;16px&quot; padding-bottom=&quot;20px&quot;&gt;From first shot to flawless routine—meet the machines designed to fit your counter and elevate your ritual.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot; aria-label=&quot;Shop the espresso collection now&quot;&gt;Shop the Collection&lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;13px&quot; padding-top=&quot;14px&quot; css-class=&quot;muted&quot;&gt;Free advice. Easy returns. Enthusiast-approved machines.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Trust/Value props --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;18px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;13px&quot; color=&quot;#6b6b6b&quot;&gt;
#           • Expert curation • Honest guidance • Coffee-first support
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Products Grid --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;eyebrow&quot;&gt;Featured Machines&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;22px&quot; font-weight=&quot;700&quot; padding-bottom=&quot;4px&quot;&gt;Find your perfect pull&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#6b6b6b&quot; font-size=&quot;14px&quot; padding-bottom=&quot;20px&quot;&gt;Thoughtfully chosen for reliability, craftsmanship, and cup quality.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;0 16px 22px&quot;&gt;
#       &lt;!-- Bianca --&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;12px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Lelit Bianca espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-top=&quot;10px&quot;&gt;Bianca&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#6b6b6b&quot; font-size=&quot;14px&quot; padding-top=&quot;4px&quot;&gt;Artful control and barista-grade consistency in a home-friendly form.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#6C483B&quot; padding-top=&quot;10px&quot; aria-label=&quot;Explore Bianca&quot;&gt;Explore Bianca&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#
#       &lt;!-- Elizabeth --&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;12px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-top=&quot;10px&quot;&gt;Elizabeth&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#6b6b6b&quot; font-size=&quot;14px&quot; padding-top=&quot;4px&quot;&gt;Smooth workflow, reliable heating, and everyday ease.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#6C483B&quot; padding-top=&quot;10px&quot; aria-label=&quot;Explore Elizabeth&quot;&gt;Explore Elizabeth&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;0 16px 26px&quot;&gt;
#       &lt;!-- MaraX --&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;12px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-top=&quot;10px&quot;&gt;MaraX&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#6b6b6b&quot; font-size=&quot;14px&quot; padding-top=&quot;4px&quot;&gt;Compact footprint with performance that punches above its size.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#6C483B&quot; padding-top=&quot;10px&quot; aria-label=&quot;Explore MaraX&quot;&gt;Explore MaraX&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#
#       &lt;!-- Kate --&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;12px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESKA01+-+Kate.png&quot; alt=&quot;Kate espresso machine&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-top=&quot;10px&quot;&gt;Kate&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#6b6b6b&quot; font-size=&quot;14px&quot; padding-top=&quot;4px&quot;&gt;Streamlined design meets intuitive controls for everyday excellence.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#6C483B&quot; padding-top=&quot;10px&quot; aria-label=&quot;Explore Kate&quot;&gt;Explore Kate&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Compare / Talk to Expert --&gt;
#     &lt;mj-section background-co
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, -apple-system, Segoe UI, Roboto, Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#0B3D3C&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-button background-color=&quot;#FFD166&quot; color=&quot;#0B3D3C&quot; border-radius=&quot;6px&quot; font-weight=&quot;700&quot; inner-padding=&quot;14px 22px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700;800&amp;display=swap&quot; /&gt;
#     &lt;mj-preview&gt;Silky, buttery Chilean seabass with a bright lemon–miso glaze. Dinner in 30 minutes.&lt;/mj-preview&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#F7FAF9&quot;&gt;
#     &lt;!-- Accent bar --&gt;
#     &lt;mj-section full-width=&quot;full-width&quot; background-color=&quot;#0B3D3C&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; alt=&quot;&quot; align=&quot;center&quot; padding=&quot;0px&quot; width=&quot;640px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- HERO --&gt;
#     &lt;mj-section background-url=&quot;/uploads/qpIEKrPysdDZ.jpg&quot; background-size=&quot;cover&quot; background-position=&quot;center center&quot; padding=&quot;48px 0 56px 0&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot;&gt;
#           &lt;span style=&quot;display:inline-block;background:#FFD166;color:#0B3D3C;font-weight:700;font-size:12px;letter-spacing:1px;text-transform:uppercase;padding:8px 12px;border-radius:999px;&quot;&gt;Recipe spotlight&lt;/span&gt;
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding-top=&quot;14px&quot; font-size=&quot;34px&quot; line-height=&quot;1.2&quot; color=&quot;#ffffff&quot; font-weight=&quot;800&quot; css-class=&quot;headline&quot; style=&quot;text-shadow:0 2px 12px rgba(0,0,0,.35);&quot;&gt;
#           Chilean Seabass with Lemon–Miso Glaze
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;8px 24px 22px&quot; color=&quot;#E8F3F1&quot; font-size=&quot;16px&quot; style=&quot;text-shadow:0 2px 10px rgba(0,0,0,.25);&quot;&gt;
#           Buttery, flaky and wildly simple. Two cooking paths. One show‑stopping dinner.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#recipe&quot; align=&quot;center&quot;&gt;
#           Cook This Tonight
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#E8F3F1&quot; font-size=&quot;13px&quot; padding-top=&quot;10px&quot; style=&quot;text-shadow:0 1px 8px rgba(0,0,0,.25);&quot;&gt;
#           Serves 2–3 • Prep 10 min • Cook 15–18 min • Difficulty: Easy
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Spacer --&gt;
#     &lt;mj-section padding=&quot;14px 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; alt=&quot;&quot; width=&quot;600px&quot; padding=&quot;0&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- RECIPE CARD --&gt;
#     &lt;mj-section padding=&quot;0 0 28px 0&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 24px 8px&quot;&gt;
#           &lt;a id=&quot;recipe&quot; name=&quot;recipe&quot; style=&quot;display:block;line-height:0;height:0;font-size:0;color:transparent;&quot;&gt;&amp;nbsp;&lt;/a&gt;
#           &lt;span style=&quot;font-weight:800;font-size:22px;color:#0B3D3C;&quot;&gt;Tear‑Away Recipe Card&lt;/span&gt;
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#56716F&quot; font-size=&quot;14px&quot; padding-bottom=&quot;18px&quot;&gt;Pin it. Print it. Or just keep it open on the counter.&lt;/mj-text&gt;
#
#         &lt;!-- Card container --&gt;
#         &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;0 20px 0 20px&quot; border-radius=&quot;12px&quot; css-class=&quot;recipe-card&quot; text-align=&quot;left&quot; border=&quot;1px solid #E6EEEC&quot;&gt;
#           &lt;mj-column width=&quot;100%&quot;&gt;
#             &lt;mj-text padding=&quot;22px 22px 12px 22px&quot; font-size=&quot;14px&quot; color=&quot;#7A9491&quot; align=&quot;center&quot; style=&quot;border-bottom:2px dashed #E6EEEC;&quot;&gt;
#               Chilean Seabass • Lemon–Miso Glaze • Optional Charred-Scallion Oil
#             &lt;/mj-text&gt;
#           &lt;/mj-column&gt;
#
#           &lt;!-- Ingredients + Glaze --&gt;
#           &lt;mj-column width=&quot;50%&quot; padding=&quot;18px 12px 10px 22px&quot;&gt;
#             &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;16px&quot; padding-bottom=&quot;6px&quot;&gt;You’ll need&lt;/mj-text&gt;
#             &lt;mj-text&gt;
#               - 2 Chilean seabass fillets (6–8 oz each), skin-on&lt;br/&gt;
#               - 1 tbsp neutral oil&lt;br/&gt;
#               - Kosher salt &amp; black pepper&lt;br/&gt;
#               - To serve: lemon wedges, rice, quick cukes (optional)
#             &lt;/mj-text&gt;
#             &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;16px&quot; padding=&quot;16px 0 6px&quot;&gt;Lemon–Miso glaze&lt;/mj-text&gt;
#             &lt;mj-text&gt;
#               - 2 tbsp white miso&lt;br/&gt;
#               - 1 tbsp honey or maple&lt;br/&gt;
#               - 1 tbsp rice vinegar&lt;br/&gt;
#               - 1 tbsp soy sauce or tamari&lt;br/&gt;
#               - 1 tsp grated fresh ginger&lt;br/&gt;
#               - Zest + juice of 1/2 lemon
#             &lt;/mj-text&gt;
#           &lt;/mj-column&gt;
#
#           &lt;mj-column width=&quot;50%&quot; padding=&quot;18px 22px 10px 12px&quot;&gt;
#             &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;16px&quot; padding-bottom=&quot;6px&quot;&gt;Optional scallion oil&lt;/mj-text&gt;
#             &lt;mj-text&gt;
#               - 2 scallions&lt;br/&gt;
#               - 2 tbsp olive oil&lt;br/&gt;
#               - Pinch chili flakes
#             &lt;/mj-text&gt;
#             &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;16px&quot; padding=&quot;16px 0 6px&quot;&gt;Make the glaze&lt;/mj-text&gt;
#             &lt;mj-text&gt;
#               Whisk all glaze ingredients until glossy and smooth. Set aside.
#             &lt;/mj-text&gt;
#             &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;16px&quot; padding=&quot;16px 0 6px&quot;&gt;Prep the fish&lt;/mj-text&gt;
#             &lt;mj-text&gt;
#               Pat fillets very dry. Score skin lightly 3–4 times. Season both sides with salt and pepper.
#             &lt;/mj-text&gt;
#           &lt;/mj-column&gt;
#         &lt;/mj-section&gt;
#
#         &lt;!-- Choose your path --&gt;
#         &lt;mj-section padding=&quot;0 20px 20px 20px&quot; background-color=&quot;#ffffff&quot; border-left=&quot;1px solid #E6EEEC&quot; border-right=&quot;1px solid #E6EEEC&quot; border-bottom=&quot;1px solid #E6EEEC&quot; border-radius=&quot;0 0 12px 12px&quot;&gt;
#           &lt;mj-column width=&quot;100%&quot; padding-bottom=&quot;8px&quot;&gt;
#             &lt;mj-text align=&quot;center&quot; padding=&quot;18px 16px 8px&quot; font-weight=&quot;800&quot; font-size=&quot;18px&quot;&gt;
#               Pick your path: Crispy Skillet or Oven-Roasted
#             &lt;/mj-text&gt;
#           &lt;/mj-column&gt;
#           &lt;mj-column width=&quot;50%&quot; padding=&quot;8px 14px 18px 18px&quot; background-url=&quot;/uploads/BL-jOWEdyIYp.jpg&quot; background-size=&quot;cover&quot; background-po
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Crisp skin, buttery flakes — make our 25‑minute Chilean Sea Bass tonight.&lt;/mj-preview&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#0F172A&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#0EA5A8&quot; color=&quot;#ffffff&quot; font-weight=&quot;700&quot; border-radius=&quot;8px&quot; inner-padding=&quot;16px 24px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style&gt;
#       .eyebrow { letter-spacing: .12em; text-transform: uppercase; font-size: 12px; color: #0EA5A8; }
#       .tag { background: #F0FDFA; color: #0EA5A8; border-radius: 999px; padding: 6px 12px; display: inline-block; font-weight: 600; margin-right:8px; }
#       .tiny { font-size: 12px; color: #64748B; }
#       .note { background: #F8FAFC; border: 1px solid #E2E8F0; border-radius: 12px; }
#       .stat { font-size: 14px; color: #334155; }
#       .section-title { font-size: 22px; font-weight: 800; color: #0F172A; }
#       .muted { color: #64748B; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#F1F5F9&quot;&gt;
#     &lt;mj-section padding=&quot;16px 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/NMKa-PpjGOLD.png&quot; alt=&quot;Brand header&quot; align=&quot;center&quot; padding=&quot;0 0 12px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section background-url=&quot;/uploads/o8gtNn0yeiJq.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding=&quot;56px 0 48px&quot;&gt;
#       &lt;mj-column width=&quot;600px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;eyebrow&quot;&gt;Recipe Spotlight&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;38px&quot; font-weight=&quot;900&quot; line-height=&quot;1.2&quot; padding-top=&quot;6px&quot;&gt;The 25‑Minute Chilean Sea Bass&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#E2E8F0&quot; font-size=&quot;16px&quot; padding=&quot;8px 32px 20px&quot;&gt;Crisp skin. Buttery flakes. Dinner, elevated.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#recipe&quot; align=&quot;center&quot;&gt;Get the full recipe&lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; padding-top=&quot;14px&quot;&gt;
#           &lt;span class=&quot;tag&quot;&gt;Serves 2&lt;/span&gt;
#           &lt;span class=&quot;tag&quot;&gt;One‑pan&lt;/span&gt;
#           &lt;span class=&quot;tag&quot;&gt;Weeknight‑easy&lt;/span&gt;
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;20px 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-image src=&quot;/uploads/d8FtbX8GvJh4.png&quot; alt=&quot;Decorative divider&quot; padding=&quot;0 24px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;20px 16px 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;0 12px&quot; class=&quot;muted&quot;&gt;Save, share, or screenshot — this card has everything you need.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;14px 16px 0&quot;&gt;
#       &lt;mj-column background-color=&quot;#ffffff&quot; border=&quot;1px dashed #CBD5E1&quot; border-radius=&quot;16px&quot; padding=&quot;16px 16px 24px&quot;&gt;
#         &lt;mj-text font-size=&quot;14px&quot; align=&quot;center&quot; color=&quot;#94A3B8&quot; padding=&quot;4px 0 8px&quot;&gt;✂️ Tear‑out recipe card&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;24px&quot; font-weight=&quot;800&quot; padding-bottom=&quot;10px&quot;&gt;Chilean Sea Bass with Crispy Skin&lt;/mj-text&gt;
#         &lt;mj-spacer height=&quot;6px&quot; /&gt;
#         &lt;mj-group&gt;
#           &lt;mj-column width=&quot;33%&quot;&gt;
#             &lt;mj-text css-class=&quot;section-title&quot; padding-bottom=&quot;8px&quot; font-size=&quot;18px&quot;&gt;At a glance&lt;/mj-text&gt;
#             &lt;mj-text css-class=&quot;stat&quot;&gt;⏱️ Time: 25 min&lt;/mj-text&gt;
#             &lt;mj-text css-class=&quot;stat&quot;&gt;🍽️ Serves: 2&lt;/mj-text&gt;
#             &lt;mj-text css-class=&quot;stat&quot;&gt;🔥 Skill: Easy&lt;/mj-text&gt;
#             &lt;mj-text css-class=&quot;stat&quot;&gt;🍳 Gear: Oven‑safe skillet&lt;/mj-text&gt;
#             &lt;mj-spacer height=&quot;10px&quot; /&gt;
#             &lt;mj-text css-class=&quot;muted&quot; font-size=&quot;13px&quot;&gt;Flavor notes: buttery, delicate, umami.&lt;/mj-text&gt;
#           &lt;/mj-column&gt;
#           &lt;mj-column width=&quot;67%&quot;&gt;
#             &lt;mj-text css-class=&quot;section-title&quot; padding-bottom=&quot;10px&quot; font-size=&quot;18px&quot;&gt;Steps (tap to expand)&lt;/mj-text&gt;
#             &lt;mj-accordion icon-wrapped-url=&quot;&quot; icon-unwrapped-url=&quot;&quot; icon-width=&quot;24px&quot; padding=&quot;0&quot;&gt;
#               &lt;mj-accordion-element&gt;
#                 &lt;mj-accordion-title&gt;1 — Prep (5 min)&lt;/mj-accordion-title&gt;
#                 &lt;mj-accordion-text&gt;
#                   Pat fillets dry. Season both sides with kosher salt and black pepper.
#                   Optional glaze: whisk 1 tbsp white miso, 1 tbsp honey, 1 tbsp mirin, 1 tsp soy.
#                 &lt;/mj-accordion-text&gt;
#               &lt;/mj-accordion-element&gt;
#               &lt;mj-accordion-element&gt;
#                 &lt;mj-accordion-title&gt;2 — Sear (4–5 min)&lt;/mj-accordion-title&gt;
#                 &lt;mj-accordion-text&gt;
#                   Heat 1 tbsp neutral oil over medium‑high. Place fish skin‑side down; press lightly for 20–30 sec to keep flat. Cook until skin is deeply golden and crisp.
#                 &lt;/mj-accordion-text&gt;
#               &lt;/mj-accordion-element&gt;
#               &lt;mj-accordion-element&gt;
#                 &lt;mj-accordion-title&gt;3 — Oven finish (4–6 min)&lt;/mj-accordion-title&gt;
#                 &lt;mj-accordion-text&gt;
#                   Add 1 tbsp butter, a smashed garlic clove, and a sprig of thyme; baste 30 sec. Transfer skillet to a 400°F (205°C) oven until internal temp reaches 130–135°F (54–57°C).
#                 &lt;/mj-accordion-text&gt;
#               &lt;/mj-accordion-element&gt;
#               &lt;mj-accordion-element&gt;
#                 &lt;mj-accordion-title&gt;4 — Finish &amp; serve&lt;/mj-accordion-title&gt;
#                 &lt;mj-accordion-text&gt;
#                   Brush with miso glaze or finish with lemon and chives. Serve with jasmine rice and quick‑sautéed greens.
#                 &lt;/mj-accordion-text&gt;
#               &lt;/mj-accordion-element&gt;
#             &lt;/mj-accordion&gt;
#           &lt;/mj-column&gt;
#         &lt;/mj-group&gt;
#         &lt;mj-spacer height=&quot;12px&quot; /&gt;
#         &lt;mj-divider border-color=&quot;#E2E8F0&quot; border-width=&quot;1px&quot; /&gt;
#         &lt;mj-text css-class=&quot;muted&quot; font-size=&quot;13px&quot; padding-top=&quot;8px&quot;&gt;Chef tip: For ultra‑crispy skin, refrigerate uncovered for 30–60 min before cooking to dry the surface.&lt;/mj-text&gt;
#         &lt;mj-group&gt;
#           &lt;mj-column&gt;
#             &lt;mj-button href=&quot;https://example.com/recipes/chilean-sea-bass&quot; align=&quot;left&quot;&gt;Get the full recipe&lt;/mj-button&gt;
#           &lt;/mj-column&gt;
#           &lt;mj-column&gt;
#             &lt;mj-button href=&quot;https://ex
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text font-size=&quot;16px&quot; color=&quot;#18222D&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#227C9D&quot; color=&quot;#ffffff&quot; border-radius=&quot;6px&quot; inner-padding=&quot;14px 22px&quot; font-weight=&quot;700&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&amp;display=swap&quot; /&gt;
#     &lt;mj-font name=&quot;Playfair Display&quot; href=&quot;https://fonts.googleapis.com/css2?family=Playfair+Display:wght@700&amp;display=swap&quot; /&gt;
#     &lt;mj-preview&gt;Join Portsmouth’s quilters—novice to advanced—for a day of stitching, learning, and community.&lt;/mj-preview&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFF8F3&quot;&gt;
#     &lt;!-- Header --&gt;
#     &lt;mj-section padding=&quot;20px 0 0&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;12px&quot; color=&quot;#7A8796&quot;&gt;Can’t see images? View in browser&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;700&quot; font-size=&quot;22px&quot; color=&quot;#18222D&quot; padding=&quot;10px 24px 0&quot;&gt;
#           Annual Create‑A‑Quilt • Portsmouth, NH
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;13px&quot; color=&quot;#227C9D&quot; padding=&quot;0 24px 18px&quot;&gt;A community stitch‑in for all skill levels&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Hero with background --&gt;
#     &lt;mj-section background-url=&quot;/uploads/bHyb-RbQe-aY.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding=&quot;48px 16px&quot;&gt;
#       &lt;mj-column background-color=&quot;#ffffff&quot; border-radius=&quot;14px&quot; padding=&quot;0&quot; border=&quot;1px solid #F1E7DF&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;22px 24px 0&quot; color=&quot;#9B6B43&quot; font-size=&quot;12px&quot; letter-spacing=&quot;1.5px&quot; text-transform=&quot;uppercase&quot;&gt;
#           Community Event
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;6px 24px 0&quot; font-family=&quot;Playfair Display, Georgia, serif&quot; font-size=&quot;30px&quot; font-weight=&quot;700&quot; color=&quot;#18222D&quot; line-height=&quot;1.25&quot;&gt;
#           Stitch Something New—Together
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;12px 28px 8px&quot; font-size=&quot;16px&quot; color=&quot;#304154&quot;&gt;
#           Bringing together novice and advanced quilters from around Portsmouth, NH to create beautiful new designs in one inspiring day.
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;14px&quot; color=&quot;#5B6B7A&quot; padding=&quot;0 24px 18px&quot;&gt;
#           📅 Sat, [Month] [Day], [Year] • ⏰ [Start–End Time] • 📍 [Venue], Portsmouth, NH
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;[Primary CTA URL]&quot; align=&quot;center&quot;&gt;
#           Reserve Your Seat
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#5B6B7A&quot; font-size=&quot;13px&quot; padding=&quot;10px 24px 24px&quot;&gt;
#           All skill levels welcome • Limited spots • Early‑bird ends [Date]
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Three key points --&gt;
#     &lt;mj-section background-color=&quot;#FFF1E8&quot; padding=&quot;22px 16px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#9B6B43&quot; font-size=&quot;12px&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;1.5px&quot; padding=&quot;0 0 6px&quot;&gt;Why join&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;18px&quot; font-weight=&quot;700&quot; color=&quot;#18222D&quot; padding=&quot;0 0 14px&quot;&gt;Create • Learn • Connect&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#     &lt;mj-section background-color=&quot;#FFF1E8&quot; padding=&quot;0 16px 24px&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;8px&quot;&gt;
#           &lt;mj-text font-weight=&quot;700&quot; color=&quot;#18222D&quot; padding-bottom=&quot;6px&quot;&gt;Hands‑on making&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#304154&quot;&gt;Design blocks, learn techniques, and contribute to a community quilt.&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column padding=&quot;8px&quot;&gt;
#           &lt;mj-text font-weight=&quot;700&quot; color=&quot;#18222D&quot; padding-bottom=&quot;6px&quot;&gt;Tracks for every level&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#304154&quot;&gt;Beginner basics, modern improv piecing, free‑motion, and more.&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#         &lt;mj-column padding=&quot;8px&quot;&gt;
#           &lt;mj-text font-weight=&quot;700&quot; color=&quot;#18222D&quot; padding-bottom=&quot;6px&quot;&gt;Local community&lt;/mj-text&gt;
#           &lt;mj-text color=&quot;#304154&quot;&gt;Meet Portsmouth makers, swap fabric, and share ideas.&lt;/mj-text&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Two columns: tracks + what to bring --&gt;
#     &lt;mj-section background-color=&quot;#ffffff&quot; padding=&quot;24px 16px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;8px&quot;&gt;
#         &lt;mj-text color=&quot;#9B6B43&quot; font-size=&quot;12px&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;1.5px&quot; padding=&quot;0 0 6px&quot;&gt;Choose your path&lt;/mj-text&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; color=&quot;#18222D&quot; padding=&quot;0 0 10px&quot;&gt;Workshops &amp; mini‑sessions&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#304154&quot;&gt;
#           • First Stitches: Quilt 101&lt;br/&gt;
#           • Modern Improv Piecing&lt;br/&gt;
#           • Color &amp; Contrast for Quilts&lt;br/&gt;
#           • Free‑Motion Quilting Basics&lt;br/&gt;
#           • Block Remix: Traditional → Modern
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;[See Full Schedule URL]&quot; background-color=&quot;#E06C4E&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot; padding=&quot;14px 0 0&quot;&gt;
#           See Full Schedule
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;8px&quot;&gt;
#         &lt;mj-text color=&quot;#9B6B43&quot; font-size=&quot;12px&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;1.5px&quot; padding=&quot;0 0 6px&quot;&gt;What to bring&lt;/mj-text&gt;
#         &lt;mj-text font-weight=&quot;700&quot; font-size=&quot;18px&quot; color=&quot;#18222D&quot; padding=&quot;0 0 10px&quot;&gt;Pack your tote&lt;/mj-text&gt;
#         &lt;mj-text color=&quot;#304154&quot;&gt;
#           • Fabric scraps or fat quarters&lt;br/&gt;
#           • Rotary cutter, ruler, and mat&lt;br/&gt;
#           • Thread, pins, seam ripper&lt;br/&gt;
#           • Sewing machine (optional)
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;[Loaner Request URL]&quot; background-color=&quot;#227C9D&quot; inner-padding=&quot;10px 16px
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-title&gt;Create‑A‑Quilt Day • Portsmouth, NH&lt;/mj-title&gt;
#     &lt;mj-preview&gt;Stitch, swap, and design together — all levels welcome. Save your seat today.&lt;/mj-preview&gt;
#     &lt;mj-font name=&quot;Poppins&quot; href=&quot;https://fonts.googleapis.com/css2?family=Poppins:wght@400;600;700&amp;amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Poppins, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2F2F2F&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#D84E55&quot; color=&quot;#ffffff&quot; font-weight=&quot;600&quot; border-radius=&quot;8px&quot; padding=&quot;16px 28px&quot; inner-padding=&quot;14px 24px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFF8F3&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/bHyb-RbQe-aY.jpg&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding-top=&quot;72px&quot; padding-bottom=&quot;72px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; font-size=&quot;28px&quot; font-weight=&quot;700&quot; padding-bottom=&quot;4px&quot; css-class=&quot;hero-title&quot; letter-spacing=&quot;0.2px&quot;&gt;
#           Annual Create‑A‑Quilt Day
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;16px&quot; font-weight=&quot;600&quot; padding=&quot;0 24px 18px&quot; letter-spacing=&quot;0.3px&quot;&gt;
#           Portsmouth, NH • Saturday, [Month] [Day], [Year] • 10:00 AM–4:00 PM
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/register&quot; align=&quot;center&quot;&gt;
#           Save Your Seat
#         &lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#FFFFFF&quot; font-size=&quot;12px&quot; padding-top=&quot;10px&quot; opacity=&quot;0.9&quot;&gt;
#           Free to attend • Space is limited • All levels welcome
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Intro Card --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;24px&quot; padding-bottom=&quot;0&quot;&gt;
#       &lt;mj-column background-color=&quot;#FFFFFF&quot; border=&quot;2px dashed #EBC8B0&quot; border-radius=&quot;14px&quot; padding=&quot;24px&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#D84E55&quot; font-size=&quot;12px&quot; font-weight=&quot;700&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;1px&quot; padding-bottom=&quot;8px&quot;&gt;
#           Stitch • Swap • Design Together
#         &lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; font-size=&quot;20px&quot; font-weight=&quot;700&quot; padding=&quot;0 10px 10px&quot;&gt;
#           Bring your imagination—leave with new skills, new friends, and a block you love.
#         &lt;/mj-text&gt;
#         &lt;mj-text padding-top=&quot;0&quot;&gt;
#           Our annual Create‑A‑Quilt event brings novice and advanced quilters from across Portsmouth together to experiment with color, learn bite‑size techniques, and start beautiful new designs. Drop in for a workshop, collaborate on a community quilt, and enjoy a day of making.
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/register&quot; align=&quot;center&quot; background-color=&quot;#2D6A4F&quot; padding-top=&quot;12px&quot;&gt;
#           Register Free
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Event Details --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;24px&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-size=&quot;14px&quot; color=&quot;#6C6C6C&quot; font-weight=&quot;700&quot; text-transform=&quot;uppercase&quot; letter-spacing=&quot;1px&quot; padding-bottom=&quot;6px&quot;&gt;
#           Event Details
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           • When: Saturday, [Month] [Day], [Year], 10:00 AM–4:00 PM
#           &lt;br/&gt;• Where: Portsmouth, NH (venue announced soon)
#           &lt;br/&gt;• Who: Beginners, hobbyists, and seasoned quilters—everyone’s welcome
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- What to Expect --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;8px&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column background-color=&quot;#FFFFFF&quot; border-radius=&quot;12px&quot; padding=&quot;20px&quot;&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-bottom=&quot;6px&quot;&gt;What to expect&lt;/mj-text&gt;
#         &lt;mj-text padding-top=&quot;0&quot;&gt;
#           • Hands‑on mini workshops for every level
#           &lt;br/&gt;• Fabric scrap swap table
#           &lt;br/&gt;• Design wall + color play corner
#           &lt;br/&gt;• Community quilt build for a local cause
#           &lt;br/&gt;• Pop‑up vendor nook + giveaways
#         &lt;/mj-text&gt;
#         &lt;mj-button href=&quot;https://example.com/schedule&quot; background-color=&quot;#D84E55&quot; padding-top=&quot;10px&quot;&gt;
#           See Schedule
#         &lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Inspiration Grid --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;8px&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text font-weight=&quot;700&quot; padding-bottom=&quot;10px&quot;&gt;Inspiration from last year&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;0&quot; padding-bottom=&quot;0&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;4px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/IE9az4JoTkMu.png&quot; alt=&quot;Vibrant quilt square pattern&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;4px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/KcswBqLO-Ff_.png&quot; alt=&quot;Geometric patchwork detail&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;0&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;4px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/N4807TOO3CUx.png&quot; alt=&quot;Color study for quilting&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;50%&quot; padding=&quot;4px&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/hA2OiBty-zz0.png&quot; alt=&quot;Modern quilt block inspiration&quot; padding=&quot;0&quot; border-radius=&quot;12px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- What to Bring + Snapshot --&gt;
#     &lt;mj-section background-color=&quot;#FFF8F3&quot; padding-top=&quot;8px&quot; padding-bottom=&quot;8px&quot;&gt;
#       &lt;mj-column background-color=&quot;#FFFFFF&quot; border-radius=&quot;12px&quot; padding=&quot;20px&quot;&gt;
# ...
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Meet your new morning ritual — our latest espresso machines are here.&lt;/mj-preview&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Helvetica, Arial, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2B2B2B&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#C38E4A&quot; color=&quot;#ffffff&quot; font-weight=&quot;700&quot; border-radius=&quot;6px&quot; inner-padding=&quot;14px 22px&quot; /&gt;
#       &lt;mj-section background-color=&quot;#FAF6F1&quot; padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .eyebrow { text-transform: uppercase; letter-spacing: 1.6px; font-size: 12px; color:#8A7C6E; }
#       .h1 { font-size: 36px; line-height: 1.2; font-weight: 800; }
#       .h2 { font-size: 22px; line-height: 1.3; font-weight: 700; }
#       .muted { color:#6D6256; }
#       .card { background:#FFFFFF; border-radius: 10px; }
#       .divider { border-top:1px solid #E8E2DA; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#FFFFFF&quot; width=&quot;600px&quot;&gt;
#     &lt;!-- Hero: New Collection --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding=&quot;40px 0 50px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-spacer height=&quot;10px&quot; /&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; css-class=&quot;eyebrow&quot;&gt;Just arrived&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot; css-class=&quot;h1&quot;&gt;Meet the New Espresso Collection&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; color=&quot;#ffffff&quot;&gt;From compact workhorses to flagship dual‑boilers—discover barista‑level results at home.&lt;/mj-text&gt;
#         &lt;mj-spacer height=&quot;8px&quot; /&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot;&gt;Shop the Collection&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Featured Machines --&gt;
#     &lt;mj-section padding=&quot;28px 24px 8px&quot; background-color=&quot;#FAF6F1&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;h2&quot;&gt;Handpicked favorites from the lineup&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;muted&quot;&gt;Thoughtfully curated for control, consistency, and everyday joy.&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;mj-section padding=&quot;8px 16px 24px&quot; background-color=&quot;#FAF6F1&quot;&gt;
#       &lt;mj-group&gt;
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Lelit Bianca dual-boiler espresso machine&quot; padding=&quot;16px 16px 0&quot; /&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;12px 16px 0&quot; font-weight=&quot;700&quot;&gt;Lelit Bianca&lt;/mj-text&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;6px 16px 12px&quot; css-class=&quot;muted&quot;&gt;Flagship control for the espresso experimenter.&lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot; padding=&quot;0 16px 16px&quot;&gt;Shop Bianca&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Lelit Elizabeth compact espresso machine&quot; padding=&quot;16px 16px 0&quot; /&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;12px 16px 0&quot; font-weight=&quot;700&quot;&gt;Lelit Elizabeth&lt;/mj-text&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;6px 16px 12px&quot; css-class=&quot;muted&quot;&gt;Compact power for effortless daily espresso.&lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot; padding=&quot;0 16px 16px&quot;&gt;Shop Elizabeth&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#
#         &lt;mj-column padding=&quot;10px&quot;&gt;
#           &lt;mj-wrapper padding=&quot;0&quot; css-class=&quot;card&quot;&gt;
#             &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;Lelit MaraX heat-exchanger espresso machine&quot; padding=&quot;16px 16px 0&quot; /&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;12px 16px 0&quot; font-weight=&quot;700&quot;&gt;Lelit MaraX&lt;/mj-text&gt;
#             &lt;mj-text align=&quot;left&quot; padding=&quot;6px 16px 12px&quot; css-class=&quot;muted&quot;&gt;Heat‑exchanger ease with remarkably stable temps.&lt;/mj-text&gt;
#             &lt;mj-button href=&quot;#&quot; inner-padding=&quot;10px 16px&quot; font-size=&quot;14px&quot; padding=&quot;0 16px 16px&quot;&gt;Shop MaraX&lt;/mj-button&gt;
#           &lt;/mj-wrapper&gt;
#         &lt;/mj-column&gt;
#       &lt;/mj-group&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Help Choosing --&gt;
#     &lt;mj-section background-color=&quot;#FAF6F1&quot; padding=&quot;8px 24px 32px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; font-weight=&quot;700&quot;&gt;Not sure which one fits your routine?&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;muted&quot;&gt;We’ll help you dial in the perfect match for your space, taste, and budget.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot; background-color=&quot;#2F2A25&quot;&gt;Compare Models&lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; padding=&quot;8px 0 0&quot;&gt;&lt;a href=&quot;#&quot; style=&quot;color:#C38E4A; text-decoration:none;&quot;&gt;Talk to a specialist →&lt;/a&gt;&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Divider --&gt;
#     &lt;mj-section padding=&quot;0 24px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-divider border-color=&quot;#E8E2DA&quot; border-width=&quot;1px&quot; /&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us --&gt;
#     &lt;mj-section padding=&quot;24px 24px 8px&quot;&gt;
#       &lt;mj-column width=&quot;40%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/about-us-manifesto.png&quot; alt=&quot;Our coffee craft manifesto&quot; padding=&quot;0 0 10px&quot; /&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;60%&quot;&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot;&gt;About us&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;h2&quot;&gt;We’re here to make better coffee feel easy&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;muted&quot;&gt;We curate equipment we truly believe in, then back it with honest guidance and friendly support. From your first espresso to your thousandth, we’re right there with you.&lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           • Thoughtful curation over endless catalogs&lt;br/&gt;
#           • Real‑world testing and recommendations&lt;br/&gt;
#           • Service‑first support from coffee people&lt;br/&gt;
#           • Long‑term care, maintenance
#     <div style="display:flex; font-family:monospace;">
#        <div style="flex:1;">
#             <div style="font-size:8pt; background:#f5f5f5; border-radius:4px; overflow:auto; padding-top:10px;">
#
#                 <div style="font-size:16pt; font-weight:bold; margin-top:20px;">Email MJML</div><br>
#                 <div style="font-size:8pt; white-space: pre-wrap;">&lt;mjml&gt;
#   &lt;mj-head&gt;
#     &lt;mj-preview&gt;Welcome—meet our new espresso machine collection, crafted for your best coffee at home.&lt;/mj-preview&gt;
#     &lt;mj-font name=&quot;Inter&quot; href=&quot;https://fonts.googleapis.com/css2?family=Inter:wght@400;600;700&amp;display=swap&quot; /&gt;
#     &lt;mj-attributes&gt;
#       &lt;mj-all font-family=&quot;Inter, Arial, Helvetica, sans-serif&quot; /&gt;
#       &lt;mj-text color=&quot;#2B2B2B&quot; font-size=&quot;16px&quot; line-height=&quot;1.6&quot; /&gt;
#       &lt;mj-button background-color=&quot;#C27A3A&quot; color=&quot;#FFFFFF&quot; inner-padding=&quot;14px 22px&quot; border-radius=&quot;6px&quot; font-weight=&quot;700&quot; font-size=&quot;14px&quot; /&gt;
#       &lt;mj-section padding=&quot;0px&quot; /&gt;
#       &lt;mj-column padding=&quot;0px&quot; /&gt;
#     &lt;/mj-attributes&gt;
#     &lt;mj-style inline=&quot;inline&quot;&gt;
#       .eyebrow { letter-spacing: 0.12em; text-transform: uppercase; font-size: 12px; color: #C27A3A; }
#       .hero-eyebrow { color:#FFFFFF; opacity:0.9; }
#       .hero-title { font-size: 34px; line-height: 1.15; font-weight: 800; color: #FFFFFF; }
#       .hero-sub { color:#FFFFFF; opacity:0.95; }
#       .ghost-link { color:#FFFFFF !important; text-decoration: underline; font-weight:600; }
#       .section-title { font-size: 24px; font-weight: 800; line-height:1.25; }
#       .card-title { font-size:18px; font-weight:800; margin:0; }
#       .muted { color:#666666; }
#       .chip { display:inline-block; padding:6px 10px; border:1px solid #E8E2D9; border-radius:999px; font-size:12px; color:#6A5E52; background:#FBF9F5; margin-right:6px; margin-bottom:6px; }
#       .foot-link { color:#6A5E52 !important; text-decoration: underline; }
#     &lt;/mj-style&gt;
#   &lt;/mj-head&gt;
#   &lt;mj-body background-color=&quot;#F7F4EF&quot;&gt;
#     &lt;!-- Hero --&gt;
#     &lt;mj-section background-url=&quot;/uploads/HP-Coffee machines.webp&quot; background-size=&quot;cover&quot; background-repeat=&quot;no-repeat&quot; background-position=&quot;center center&quot; padding=&quot;50px 20px 60px 20px&quot;&gt;
#       &lt;mj-column width=&quot;100%&quot;&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;eyebrow hero-eyebrow&quot;&gt;Welcome&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;hero-title&quot;&gt;Introducing the New Espresso Collection&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;hero-sub&quot;&gt;From first dial-in to last sip—café-level performance for your countertop.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; align=&quot;center&quot; padding-top=&quot;18px&quot;&gt;Shop the Collection&lt;/mj-button&gt;
#         &lt;mj-text align=&quot;center&quot; padding-top=&quot;10px&quot;&gt;
#           &lt;a class=&quot;ghost-link&quot; href=&quot;#&quot; style=&quot;color:#FFFFFF; text-decoration:underline;&quot;&gt;Compare models →&lt;/a&gt;
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Intro text --&gt;
#     &lt;mj-section padding=&quot;24px 20px 8px 20px&quot; background-color=&quot;#FFFFFF&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;muted&quot;&gt;
#           Meticulously selected machines for beginners, tinkerers, and daily ritualists—each tuned for reliability, texture, and repeatable results.
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Product Grid --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;8px 20px 24px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot; css-class=&quot;section-title&quot;&gt;Meet the machines&lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;0 20px 8px 20px&quot;&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESBN03-LELIT-Bianca_01.png&quot; alt=&quot;Bianca espresso machine&quot; padding=&quot;0 0 10px 0&quot; width=&quot;190px&quot; /&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;0 10px&quot; css-class=&quot;card-title&quot;&gt;Bianca&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;6px 10px&quot; css-class=&quot;muted&quot;&gt;For the home barista who loves nuance and silky texture—crafted for expressive extractions.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; padding=&quot;6px 10px 0 10px&quot;&gt;Explore Bianca&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PDP-PESEL01-Elizabeth-01.png&quot; alt=&quot;Elizabeth espresso machine&quot; padding=&quot;0 0 10px 0&quot; width=&quot;190px&quot; /&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;0 10px&quot; css-class=&quot;card-title&quot;&gt;Elizabeth&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;6px 10px&quot; css-class=&quot;muted&quot;&gt;Effortless, everyday excellence—balanced performance for milk drinks and straight shots.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; padding=&quot;6px 10px 0 10px&quot;&gt;Explore Elizabeth&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#       &lt;mj-column width=&quot;33%&quot;&gt;
#         &lt;mj-image src=&quot;/uploads/PESMX02_MaraX-01.png&quot; alt=&quot;MaraX espresso machine&quot; padding=&quot;0 0 10px 0&quot; width=&quot;190px&quot; /&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;0 10px&quot; css-class=&quot;card-title&quot;&gt;MaraX&lt;/mj-text&gt;
#         &lt;mj-text align=&quot;left&quot; padding=&quot;6px 10px&quot; css-class=&quot;muted&quot;&gt;Compact footprint, confident steam—your entry to authentic café workflow at home.&lt;/mj-text&gt;
#         &lt;mj-button href=&quot;#&quot; padding=&quot;6px 10px 0 10px&quot;&gt;Explore MaraX&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Feature chips --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;0 20px 24px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-text align=&quot;center&quot;&gt;
#           &lt;span class=&quot;chip&quot;&gt;Barista‑vetted&lt;/span&gt;
#           &lt;span class=&quot;chip&quot;&gt;Curated selection&lt;/span&gt;
#           &lt;span class=&quot;chip&quot;&gt;Responsive support&lt;/span&gt;
#           &lt;span class=&quot;chip&quot;&gt;Built to last&lt;/span&gt;
#         &lt;/mj-text&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- Secondary CTA Row --&gt;
#     &lt;mj-section background-color=&quot;#FFFFFF&quot; padding=&quot;0 20px 32px 20px&quot;&gt;
#       &lt;mj-column&gt;
#         &lt;mj-button href=&quot;#&quot; background-color=&quot;#2B2B2B&quot; align=&quot;center&quot;&gt;See all models&lt;/mj-button&gt;
#       &lt;/mj-column&gt;
#     &lt;/mj-section&gt;
#
#     &lt;!-- About Us --&gt;
#     &lt;mj-section padding=&quot;40px 20px&quot; background-color=&quot;#FBF9F5&quot;&gt;
#       &lt;mj-column width=&quot;60%&quot;&gt;
#         &lt;mj-text css-class=&quot;eyebrow&quot;&gt;About us&lt;/mj-text&gt;
#         &lt;mj-text css-class=&quot;section-title&quot;&gt;We’re here for your coffee journey&lt;/mj-text&gt;
#         &lt;mj-text class=&quot;muted&quot;&gt;
#           We’re a team of espresso enthusiasts helping people brew better at home. From honest guidance to long‑term care, our focus is your perfect cup.
#         &lt;/mj-text&gt;
#         &lt;mj-text&gt;
#           • Curated gear we’d use ourselves&lt;br /&gt;
#           • Clear, human support when y
